# %%
import requests

# %% [markdown]
# # Basic Stats

# %%
url = "http://www.nhl.com/stats/rest/skaters?isAggregate=false&reportType=basic&isGame=false&reportName=skatersummary&sort=[{%22property%22:%22points%22,%22direction%22:%22DESC%22},{%22property%22:%22goals%22,%22direction%22:%22DESC%22},{%22property%22:%22assists%22,%22direction%22:%22DESC%22}]&cayenneExp=gameTypeId=2%20and%20seasonId%3E=20172018%20and%20seasonId%3C=20172018"
data = requests.get(url).json()["data"]

# %%
out = {p["playerName"] : {"g": p["goals"], "a": p["assists"], "gp" : p["gamesPlayed"], "s%" : p["shootingPctg"], "s" : p["shots"], "toi" : p["timeOnIcePerGame"]} for p in data}

# %% [markdown]
# # Blocked Shots

# %%
url = "http://www.nhl.com/stats/rest/skaters?isAggregate=false&reportType=basic&isGame=false&reportName=realtime&sort=[{%22property%22:%22hits%22,%22direction%22:%22DESC%22}]&cayenneExp=gameTypeId=2%20and%20seasonId%3E=20172018%20and%20seasonId%3C=20172018"
data = requests.get(url).json()["data"]

# %%
for p in data:
    out[p["playerName"]].update({"bs" : p["blockedShots"]})

# %%
out
# Out:
# {'A.J. Greer': {'a': 1,
#   'bs': 2,
#   'g': 0,
#   'gp': 6,
#   's': 6,
#   's%': 0.0,
#   'toi': 490.1666},
#  'Aaron Ekblad': {'a': 5,
#   'bs': 26,
#   'g': 3,
#   'gp': 16,
#   's': 38,
#   's%': 0.0789,
#   'toi': 1425.25},
#  'Aaron Ness': {'a': 1,
#   'bs': 8,
#   'g': 0,
#   'gp': 8,
#   's': 2,
#   's%': 0.0,
#   'toi': 763.625},
#  'Adam Clendening': {'a': 2,
#   'bs': 6,
#   'g': 0,
#   'gp': 5,
#   's': 4,
#   's%': 0.0,
#   'toi': 956.0},
#  'Adam Cracknell': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 6,
#   's%': 0.0,
#   'toi': 462.6},
#  'Adam Henrique': {'a': 6,
#   'bs': 6,
#   'g': 3,
#   'gp': 17,
#   's': 31,
#   's%': 0.0967,
#   'toi': 1115.4705},
#  'Adam Larsson': {'a': 1,
#   'bs': 29,
#   'g': 2,
#   'gp': 17,
#   's': 34,
#   's%': 0.0588,
#   'toi': 1315.8823},
#  'Adam Lowry': {'a': 0,
#   'bs': 8,
#   'g': 1,
#   'gp': 7,
#   's': 12,
#   's%': 0.0833,
#   'toi': 914.5714},
#  'Adam McQuaid': {'a': 1,
#   'bs': 10,
#   'g': 0,
#   'gp': 6,
#   's': 6,
#   's%': 0.0,
#   'toi': 881.8333},
#  'Adam Pelech': {'a': 5,
#   'bs': 20,
#   'g': 0,
#   'gp': 13,
#   's': 7,
#   's%': 0.0,
#   'toi': 1105.0769},
#  'Adrian Kempe': {'a': 4,
#   'bs': 6,
#   'g': 7,
#   'gp': 16,
#   's': 23,
#   's%': 0.3043,
#   'toi': 746.9375},
#  'Alan Quine': {'a': 1,
#   'bs': 1,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 767.0},
#  'Alec Martinez': {'a': 2,
#   'bs': 48,
#   'g': 2,
#   'gp': 14,
#   's': 27,
#   's%': 0.074,
#   'toi': 1526.0},
#  'Aleksander Barkov': {'a': 12,
#   'bs': 13,
#   'g': 5,
#   'gp': 16,
#   's': 42,
#   's%': 0.119,
#   'toi': 1347.0625},
#  'Ales Hemsky': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 7,
#   's': 5,
#   's%': 0.0,
#   'toi': 595.2857},
#  'Alex Biega': {'a': 1,
#   'bs': 14,
#   'g': 0,
#   'gp': 10,
#   's': 14,
#   's%': 0.0,
#   'toi': 811.4},
#  'Alex Chiasson': {'a': 1,
#   'bs': 5,
#   'g': 1,
#   'gp': 17,
#   's': 22,
#   's%': 0.0454,
#   'toi': 746.8823},
#  'Alex DeBrincat': {'a': 5,
#   'bs': 6,
#   'g': 6,
#   'gp': 18,
#   's': 33,
#   's%': 0.1818,
#   'toi': 843.8888},
#  'Alex Formenton': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 294.0},
#  'Alex Galchenyuk': {'a': 2,
#   'bs': 8,
#   'g': 4,
#   'gp': 18,
#   's': 42,
#   's%': 0.0952,
#   'toi': 898.7222},
#  'Alex Goligoski': {'a': 7,
#   'bs': 20,
#   'g': 1,
#   'gp': 19,
#   's': 24,
#   's%': 0.0416,
#   'toi': 1371.3684},
#  'Alex Iafallo': {'a': 5,
#   'bs': 3,
#   'g': 1,
#   'gp': 17,
#   's': 40,
#   's%': 0.025,
#   'toi': 1030.2352},
#  'Alex Killorn': {'a': 11,
#   'bs': 7,
#   'g': 2,
#   'gp': 18,
#   's': 31,
#   's%': 0.0645,
#   'toi': 979.3888},
#  'Alex Ovechkin': {'a': 6,
#   'bs': 9,
#   'g': 13,
#   'gp': 18,
#   's': 80,
#   's%': 0.1625,
#   'toi': 1149.8333},
#  'Alex Petrovic': {'a': 2,
#   'bs': 14,
#   'g': 0,
#   'gp': 11,
#   's': 8,
#   's%': 0.0,
#   'toi': 871.0},
#  'Alex Pietrangelo': {'a': 9,
#   'bs': 31,
#   'g': 7,
#   'gp': 18,
#   's': 61,
#   's%': 0.1147,
#   'toi': 1582.0},
#  'Alex Tuch': {'a': 3,
#   'bs': 6,
#   'g': 4,
#   'gp': 12,
#   's': 28,
#   's%': 0.1428,
#   'toi': 871.0833},
#  'Alexander Burmistrov': {'a': 4,
#   'bs': 1,
#   'g': 1,
#   'gp': 15,
#   's': 15,
#   's%': 0.0666,
#   'toi': 715.4},
#  'Alexander Edler': {'a': 1,
#   'bs': 10,
#   'g': 0,
#   'gp': 5,
#   's': 9,
#   's%': 0.0,
#   'toi': 1149.8},
#  'Alexander Kerfoot': {'a': 6,
#   'bs': 5,
#   'g': 7,
#   'gp': 16,
#   's': 20,
#   's%': 0.35,
#   'toi': 791.6875},
#  'Alexander Radulov': {'a': 9,
#   'bs': 15,
#   'g': 6,
#   'gp': 17,
#   's': 39,
#   's%': 0.1538,
#   'toi': 1162.647},
#  'Alexander Steen': {'a': 5,
#   'bs': 6,
#   'g': 1,
#   'gp': 12,
#   's': 28,
#   's%': 0.0357,
#   'toi': 1120.75},
#  'Alexander Wennberg': {'a': 8,
#   'bs': 16,
#   'g': 1,
#   'gp': 18,
#   's': 29,
#   's%': 0.0344,
#   'toi': 1139.1666},
#  'Alexandre Burrows': {'a': 2,
#   'bs': 6,
#   'g': 3,
#   'gp': 16,
#   's': 23,
#   's%': 0.1304,
#   'toi': 827.0},
#  'Alexei Emelin': {'a': 2,
#   'bs': 23,
#   'g': 0,
#   'gp': 15,
#   's': 11,
#   's%': 0.0,
#   'toi': 1090.4666},
#  'Anders Bjork': {'a': 6,
#   'bs': 8,
#   'g': 3,
#   'gp': 16,
#   's': 21,
#   's%': 0.1428,
#   'toi': 868.0625},
#  'Anders Lee': {'a': 8,
#   'bs': 14,
#   'g': 9,
#   'gp': 17,
#   's': 41,
#   's%': 0.2195,
#   'toi': 1000.4705},
#  'Andre Burakovsky': {'a': 3,
#   'bs': 3,
#   'g': 1,
#   'gp': 9,
#   's': 15,
#   's%': 0.0666,
#   'toi': 944.8888},
#  'Andreas Athanasiou': {'a': 1,
#   'bs': 6,
#   'g': 2,
#   'gp': 8,
#   's': 25,
#   's%': 0.08,
#   'toi': 912.875},
#  'Andreas Borgman': {'a': 3,
#   'bs': 14,
#   'g': 2,
#   'gp': 17,
#   's': 20,
#   's%': 0.1,
#   'toi': 855.9411},
#  'Andrei Mironov': {'a': 1,
#   'bs': 5,
#   'g': 0,
#   'gp': 5,
#   's': 1,
#   's%': 0.0,
#   'toi': 644.0},
#  'Andrej Sustr': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 7,
#   's': 4,
#   's%': 0.0,
#   'toi': 532.0},
#  'Andrew Cogliano': {'a': 8,
#   'bs': 6,
#   'g': 3,
#   'gp': 17,
#   's': 37,
#   's%': 0.081,
#   'toi': 1000.5294},
#  'Andrew Copp': {'a': 1,
#   'bs': 8,
#   'g': 2,
#   'gp': 16,
#   's': 14,
#   's%': 0.1428,
#   'toi': 713.9375},
#  'Andrew Ladd': {'a': 4,
#   'bs': 7,
#   'g': 3,
#   'gp': 17,
#   's': 30,
#   's%': 0.1,
#   'toi': 993.3529},
#  'Andrew MacDonald': {'a': 0,
#   'bs': 18,
#   'g': 1,
#   'gp': 8,
#   's': 15,
#   's%': 0.0666,
#   'toi': 1175.875},
#  'Andrew Shaw': {'a': 5,
#   'bs': 10,
#   'g': 4,
#   'gp': 18,
#   's': 40,
#   's%': 0.1,
#   'toi': 995.1111},
#  'Andy Andreoff': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 15,
#   's': 16,
#   's%': 0.0,
#   'toi': 541.8666},
#  'Andy Greene': {'a': 2,
#   'bs': 34,
#   'g': 2,
#   'gp': 16,
#   's': 21,
#   's%': 0.0952,
#   'toi': 1326.5},
#  'Anthony Beauvillier': {'a': 2,
#   'bs': 6,
#   'g': 2,
#   'gp': 13,
#   's': 15,
#   's%': 0.1333,
#   'toi': 769.4615},
#  'Anthony Bitetto': {'a': 0,
#   'bs': 5,
#   'g': 0,
#   'gp': 5,
#   's': 3,
#   's%': 0.0,
#   'toi': 827.2},
#  'Anthony Duclair': {'a': 3,
#   'bs': 8,
#   'g': 3,
#   'gp': 14,
#   's': 23,
#   's%': 0.1304,
#   'toi': 801.5714},
#  'Anthony Mantha': {'a': 8,
#   'bs': 6,
#   'g': 8,
#   'gp': 18,
#   's': 46,
#   's%': 0.1739,
#   'toi': 1052.1666},
#  'Anthony Peluso': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 0,
#   's%': 0.0,
#   'toi': 278.5},
#  'Antoine Roussel': {'a': 2,
#   'bs': 6,
#   'g': 1,
#   'gp': 17,
#   's': 15,
#   's%': 0.0666,
#   'toi': 700.8235},
#  'Antoine Vermette': {'a': 3,
#   'bs': 11,
#   'g': 3,
#   'gp': 17,
#   's': 32,
#   's%': 0.0937,
#   'toi': 991.2941},
#  'Anton Lindholm': {'a': 0,
#   'bs': 14,
#   'g': 0,
#   'gp': 9,
#   's': 6,
#   's%': 0.0,
#   'toi': 926.6666},
#  'Anton Slepyshev': {'a': 1,
#   'bs': 2,
#   'g': 1,
#   'gp': 10,
#   's': 13,
#   's%': 0.0769,
#   'toi': 662.5},
#  'Anton Stralman': {'a': 4,
#   'bs': 18,
#   'g': 2,
#   'gp': 18,
#   's': 29,
#   's%': 0.0689,
#   'toi': 1247.8333},
#  'Anze Kopitar': {'a': 13,
#   'bs': 11,
#   'g': 8,
#   'gp': 17,
#   's': 44,
#   's%': 0.1818,
#   'toi': 1345.1764},
#  'Artem Anisimov': {'a': 2,
#   'bs': 7,
#   'g': 6,
#   'gp': 18,
#   's': 39,
#   's%': 0.1538,
#   'toi': 1006.0},
#  'Artemi Panarin': {'a': 10,
#   'bs': 2,
#   'g': 3,
#   'gp': 18,
#   's': 56,
#   's%': 0.0535,
#   'toi': 1234.4444},
#  'Artturi Lehkonen': {'a': 3,
#   'bs': 4,
#   'g': 2,
#   'gp': 18,
#   's': 47,
#   's%': 0.0425,
#   'toi': 996.0555},
#  'Austin Czarnik': {'a': 1,
#   'bs': 0,
#   'g': 0,
#   'gp': 6,
#   's': 4,
#   's%': 0.0,
#   'toi': 657.6666},
#  'Austin Watson': {'a': 1,
#   'bs': 23,
#   'g': 1,
#   'gp': 16,
#   's': 15,
#   's%': 0.0666,
#   'toi': 771.6875},
#  'Auston Matthews': {'a': 9,
#   'bs': 15,
#   'g': 10,
#   'gp': 16,
#   's': 53,
#   's%': 0.1886,
#   'toi': 1104.0625},
#  'Barclay Goodrow': {'a': 2,
#   'bs': 2,
#   'g': 0,
#   'gp': 5,
#   's': 10,
#   's%': 0.0,
#   'toi': 658.8},
#  'Beau Bennett': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 5,
#   's%': 0.0,
#   'toi': 630.0},
#  'Ben Chiarot': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 968.0},
#  'Ben Harpur': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 3,
#   's': 0,
#   's%': 0.0,
#   'toi': 721.3333},
#  'Ben Hutton': {'a': 3,
#   'bs': 18,
#   'g': 0,
#   'gp': 17,
#   's': 38,
#   's%': 0.0,
#   'toi': 1358.2352},
#  'Ben Lovejoy': {'a': 2,
#   'bs': 11,
#   'g': 1,
#   'gp': 7,
#   's': 7,
#   's%': 0.1428,
#   'toi': 999.5714},
#  'Benoit Pouliot': {'a': 2,
#   'bs': 7,
#   'g': 5,
#   'gp': 17,
#   's': 24,
#   's%': 0.2083,
#   'toi': 866.4117},
#  'Blake Coleman': {'a': 1,
#   'bs': 16,
#   'g': 2,
#   'gp': 17,
#   's': 33,
#   's%': 0.0606,
#   'toi': 830.1764},
#  'Blake Comeau': {'a': 4,
#   'bs': 9,
#   'g': 4,
#   'gp': 16,
#   's': 28,
#   's%': 0.1428,
#   'toi': 827.9375},
#  'Blake Wheeler': {'a': 18,
#   'bs': 7,
#   'g': 5,
#   'gp': 16,
#   's': 47,
#   's%': 0.1063,
#   'toi': 1248.0625},
#  'Bo Horvat': {'a': 7,
#   'bs': 6,
#   'g': 6,
#   'gp': 17,
#   's': 45,
#   's%': 0.1333,
#   'toi': 1121.0},
#  'Bobby Ryan': {'a': 6,
#   'bs': 7,
#   'g': 0,
#   'gp': 8,
#   's': 12,
#   's%': 0.0,
#   'toi': 979.75},
#  'Boo Nieves': {'a': 3,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 2,
#   's%': 0.0,
#   'toi': 599.0},
#  'Boone Jenner': {'a': 4,
#   'bs': 11,
#   'g': 2,
#   'gp': 11,
#   's': 28,
#   's%': 0.0714,
#   'toi': 1152.2727},
#  'Brad Hunt': {'a': 7,
#   'bs': 7,
#   'g': 0,
#   'gp': 9,
#   's': 14,
#   's%': 0.0,
#   'toi': 1159.4444},
#  'Brad Malone': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 7,
#   's': 9,
#   's%': 0.0,
#   'toi': 479.2857},
#  'Brad Marchand': {'a': 7,
#   'bs': 5,
#   'g': 8,
#   'gp': 14,
#   's': 36,
#   's%': 0.2222,
#   'toi': 1290.2142},
#  'Brad Richardson': {'a': 3,
#   'bs': 14,
#   'g': 0,
#   'gp': 17,
#   's': 27,
#   's%': 0.0,
#   'toi': 839.8823},
#  'Brady Skjei': {'a': 3,
#   'bs': 29,
#   'g': 2,
#   'gp': 18,
#   's': 38,
#   's%': 0.0526,
#   'toi': 1161.0},
#  'Brandon Carlo': {'a': 3,
#   'bs': 19,
#   'g': 0,
#   'gp': 16,
#   's': 19,
#   's%': 0.0,
#   'toi': 1139.5625},
#  'Brandon Davidson': {'a': 1,
#   'bs': 14,
#   'g': 0,
#   'gp': 10,
#   's': 12,
#   's%': 0.0,
#   'toi': 924.3},
#  'Brandon Dubinsky': {'a': 4,
#   'bs': 12,
#   'g': 2,
#   'gp': 18,
#   's': 29,
#   's%': 0.0689,
#   'toi': 1036.2777},
#  'Brandon Manning': {'a': 2,
#   'bs': 15,
#   'g': 2,
#   'gp': 12,
#   's': 23,
#   's%': 0.0869,
#   'toi': 1137.8333},
#  'Brandon Montour': {'a': 4,
#   'bs': 18,
#   'g': 5,
#   'gp': 17,
#   's': 44,
#   's%': 0.1136,
#   'toi': 1240.0},
#  'Brandon Saad': {'a': 3,
#   'bs': 9,
#   'g': 7,
#   'gp': 18,
#   's': 59,
#   's%': 0.1186,
#   'toi': 1147.5555},
#  'Brandon Sutter': {'a': 4,
#   'bs': 8,
#   'g': 1,
#   'gp': 17,
#   's': 28,
#   's%': 0.0357,
#   'toi': 1018.0588},
#  'Brandon Tanev': {'a': 2,
#   'bs': 13,
#   'g': 2,
#   'gp': 16,
#   's': 17,
#   's%': 0.1176,
#   'toi': 760.0625},
#  'Brayden McNabb': {'a': 2,
#   'bs': 34,
#   'g': 0,
#   'gp': 13,
#   's': 13,
#   's%': 0.0,
#   'toi': 1136.4615},
#  'Brayden Point': {'a': 10,
#   'bs': 11,
#   'g': 7,
#   'gp': 18,
#   's': 42,
#   's%': 0.1666,
#   'toi': 1168.3333},
#  'Brayden Schenn': {'a': 15,
#   'bs': 8,
#   'g': 5,
#   'gp': 18,
#   's': 48,
#   's%': 0.1041,
#   'toi': 1193.4444},
#  'Braydon Coburn': {'a': 5,
#   'bs': 23,
#   'g': 0,
#   'gp': 18,
#   's': 15,
#   's%': 0.0,
#   'toi': 1022.7222},
#  'Brendan Gallagher': {'a': 5,
#   'bs': 8,
#   'g': 7,
#   'gp': 18,
#   's': 55,
#   's%': 0.1272,
#   'toi': 911.7777},
#  'Brendan Gaunce': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 844.5},
#  'Brendan Leipsic': {'a': 4,
#   'bs': 4,
#   'g': 0,
#   'gp': 9,
#   's': 12,
#   's%': 0.0,
#   'toi': 771.7777},
#  'Brendan Lemieux': {'a': 0,
#   'bs': 1,
#   'g': 1,
#   'gp': 7,
#   's': 4,
#   's%': 0.25,
#   'toi': 464.0},
#  'Brendan Perlini': {'a': 1,
#   'bs': 4,
#   'g': 4,
#   'gp': 13,
#   's': 24,
#   's%': 0.1666,
#   'toi': 780.1538},
#  'Brendan Smith': {'a': 2,
#   'bs': 14,
#   'g': 0,
#   'gp': 11,
#   's': 11,
#   's%': 0.0,
#   'toi': 981.8181},
#  'Brenden Dillon': {'a': 4,
#   'bs': 19,
#   'g': 0,
#   'gp': 16,
#   's': 23,
#   's%': 0.0,
#   'toi': 1025.625},
#  'Brent Burns': {'a': 7,
#   'bs': 33,
#   'g': 0,
#   'gp': 16,
#   's': 65,
#   's%': 0.0,
#   'toi': 1484.75},
#  'Brent Seabrook': {'a': 5,
#   'bs': 37,
#   'g': 1,
#   'gp': 18,
#   's': 30,
#   's%': 0.0333,
#   'toi': 1309.7777},
#  'Brett Connolly': {'a': 1,
#   'bs': 0,
#   'g': 1,
#   'gp': 11,
#   's': 8,
#   's%': 0.125,
#   'toi': 646.3636},
#  'Brett Kulak': {'a': 3,
#   'bs': 2,
#   'g': 0,
#   'gp': 8,
#   's': 3,
#   's%': 0.0,
#   'toi': 720.0},
#  'Brett Pesce': {'a': 1,
#   'bs': 23,
#   'g': 0,
#   'gp': 13,
#   's': 19,
#   's%': 0.0,
#   'toi': 1298.0769},
#  'Brett Ritchie': {'a': 1,
#   'bs': 1,
#   'g': 1,
#   'gp': 14,
#   's': 18,
#   's%': 0.0555,
#   'toi': 704.1428},
#  'Brian Boyle': {'a': 1,
#   'bs': 5,
#   'g': 1,
#   'gp': 7,
#   's': 10,
#   's%': 0.1,
#   'toi': 852.4285},
#  'Brian Dumoulin': {'a': 0,
#   'bs': 32,
#   'g': 1,
#   'gp': 19,
#   's': 25,
#   's%': 0.04,
#   'toi': 1249.9473},
#  'Brian Gibbons': {'a': 3,
#   'bs': 15,
#   'g': 8,
#   'gp': 17,
#   's': 24,
#   's%': 0.3333,
#   'toi': 919.9411},
#  'Brock Boeser': {'a': 9,
#   'bs': 4,
#   'g': 5,
#   'gp': 14,
#   's': 36,
#   's%': 0.1388,
#   'toi': 944.7857},
#  'Brock McGinn': {'a': 4,
#   'bs': 3,
#   'g': 5,
#   'gp': 15,
#   's': 24,
#   's%': 0.2083,
#   'toi': 733.9333},
#  'Brock Nelson': {'a': 3,
#   'bs': 8,
#   'g': 5,
#   'gp': 17,
#   's': 26,
#   's%': 0.1923,
#   'toi': 866.0588},
#  'Brooks Laich': {'a': 1,
#   'bs': 5,
#   'g': 0,
#   'gp': 11,
#   's': 10,
#   's%': 0.0,
#   'toi': 683.5454},
#  'Brooks Orpik': {'a': 3,
#   'bs': 44,
#   'g': 0,
#   'gp': 18,
#   's': 9,
#   's%': 0.0,
#   'toi': 1359.0555},
#  'Bryan Little': {'a': 5,
#   'bs': 5,
#   'g': 1,
#   'gp': 16,
#   's': 16,
#   's%': 0.0625,
#   'toi': 1026.8125},
#  'Bryan Rust': {'a': 9,
#   'bs': 12,
#   'g': 2,
#   'gp': 19,
#   's': 35,
#   's%': 0.0571,
#   'toi': 1010.0526},
#  'Byron Froese': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 507.0},
#  'Cal Clutterbuck': {'a': 3,
#   'bs': 7,
#   'g': 2,
#   'gp': 14,
#   's': 19,
#   's%': 0.1052,
#   'toi': 754.5714},
#  "Cal O'Reilly": {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 1,
#   's': 1,
#   's%': 0.0,
#   'toi': 496.0},
#  'Calle Jarnkrok': {'a': 4,
#   'bs': 8,
#   'g': 3,
#   'gp': 16,
#   's': 19,
#   's%': 0.1578,
#   'toi': 942.25},
#  'Calle Rosen': {'a': 1,
#   'bs': 0,
#   'g': 0,
#   'gp': 4,
#   's': 5,
#   's%': 0.0,
#   'toi': 767.25},
#  'Calvin de Haan': {'a': 7,
#   'bs': 31,
#   'g': 0,
#   'gp': 17,
#   's': 18,
#   's%': 0.0,
#   'toi': 1125.647},
#  'Cam Atkinson': {'a': 1,
#   'bs': 8,
#   'g': 4,
#   'gp': 14,
#   's': 48,
#   's%': 0.0833,
#   'toi': 1149.0},
#  'Cam Fowler': {'a': 1,
#   'bs': 10,
#   'g': 1,
#   'gp': 7,
#   's': 10,
#   's%': 0.1,
#   'toi': 1363.4285},
#  'Carl Gunnarsson': {'a': 1,
#   'bs': 33,
#   'g': 3,
#   'gp': 17,
#   's': 16,
#   's%': 0.1875,
#   'toi': 1067.4705},
#  'Carl Hagelin': {'a': 1,
#   'bs': 9,
#   'g': 1,
#   'gp': 18,
#   's': 37,
#   's%': 0.027,
#   'toi': 964.2222},
#  'Carl Soderberg': {'a': 4,
#   'bs': 10,
#   'g': 2,
#   'gp': 13,
#   's': 19,
#   's%': 0.1052,
#   'toi': 919.2307},
#  'Carter Rowney': {'a': 1,
#   'bs': 10,
#   'g': 1,
#   'gp': 9,
#   's': 5,
#   's%': 0.2,
#   'toi': 652.7777},
#  'Casey Cizikas': {'a': 2,
#   'bs': 15,
#   'g': 4,
#   'gp': 17,
#   's': 25,
#   's%': 0.16,
#   'toi': 841.9411},
#  'Cedric Paquette': {'a': 1,
#   'bs': 2,
#   'g': 0,
#   'gp': 6,
#   's': 2,
#   's%': 0.0,
#   'toi': 593.8333},
#  'Chad Ruhwedel': {'a': 1,
#   'bs': 14,
#   'g': 0,
#   'gp': 16,
#   's': 22,
#   's%': 0.0,
#   'toi': 951.875},
#  'Chandler Stephenson': {'a': 3,
#   'bs': 4,
#   'g': 2,
#   'gp': 9,
#   's': 4,
#   's%': 0.5,
#   'toi': 749.6666},
#  'Charles Hudon': {'a': 4,
#   'bs': 6,
#   'g': 2,
#   'gp': 17,
#   's': 48,
#   's%': 0.0416,
#   'toi': 769.0588},
#  'Charlie Coyle': {'a': 2,
#   'bs': 5,
#   'g': 0,
#   'gp': 3,
#   's': 7,
#   's%': 0.0,
#   'toi': 1115.0},
#  'Charlie McAvoy': {'a': 7,
#   'bs': 19,
#   'g': 1,
#   'gp': 16,
#   's': 23,
#   's%': 0.0434,
#   'toi': 1378.75},
#  'Chase Balisy': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 4,
#   's': 3,
#   's%': 0.0,
#   'toi': 643.25},
#  'Chris Bigras': {'a': 1,
#   'bs': 14,
#   'g': 0,
#   'gp': 12,
#   's': 7,
#   's%': 0.0,
#   'toi': 875.0833},
#  'Chris Kreider': {'a': 3,
#   'bs': 6,
#   'g': 5,
#   'gp': 18,
#   's': 55,
#   's%': 0.0909,
#   'toi': 966.8333},
#  'Chris Kunitz': {'a': 3,
#   'bs': 5,
#   'g': 2,
#   'gp': 18,
#   's': 15,
#   's%': 0.1333,
#   'toi': 675.2777},
#  'Chris Stewart': {'a': 2,
#   'bs': 6,
#   'g': 6,
#   'gp': 16,
#   's': 27,
#   's%': 0.2222,
#   'toi': 774.4375},
#  'Chris Thorburn': {'a': 1,
#   'bs': 6,
#   'g': 0,
#   'gp': 9,
#   's': 4,
#   's%': 0.0,
#   'toi': 473.1111},
#  'Chris Tierney': {'a': 3,
#   'bs': 9,
#   'g': 4,
#   'gp': 16,
#   's': 20,
#   's%': 0.2,
#   'toi': 861.25},
#  'Chris Wagner': {'a': 6,
#   'bs': 9,
#   'g': 2,
#   'gp': 17,
#   's': 26,
#   's%': 0.0769,
#   'toi': 930.2352},
#  'Chris Wideman': {'a': 4,
#   'bs': 9,
#   'g': 3,
#   'gp': 15,
#   's': 24,
#   's%': 0.125,
#   'toi': 706.5333},
#  'Christian Djoos': {'a': 1,
#   'bs': 10,
#   'g': 2,
#   'gp': 15,
#   's': 14,
#   's%': 0.1428,
#   'toi': 881.8},
#  'Christian Dvorak': {'a': 8,
#   'bs': 24,
#   'g': 2,
#   'gp': 19,
#   's': 35,
#   's%': 0.0571,
#   'toi': 1052.7368},
#  'Christian Fischer': {'a': 2,
#   'bs': 4,
#   'g': 4,
#   'gp': 17,
#   's': 28,
#   's%': 0.1428,
#   'toi': 830.5294},
#  'Christian Folin': {'a': 0,
#   'bs': 12,
#   'g': 1,
#   'gp': 11,
#   's': 8,
#   's%': 0.125,
#   'toi': 888.8181},
#  'Christian Jaros': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 0,
#   's%': 0.0,
#   'toi': 478.0},
#  'Christoph Bertschy': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 323.0},
#  'Christopher DiDomenico': {'a': 3,
#   'bs': 5,
#   'g': 3,
#   'gp': 9,
#   's': 8,
#   's%': 0.375,
#   'toi': 671.1111},
#  'Christopher Tanev': {'a': 3,
#   'bs': 18,
#   'g': 2,
#   'gp': 15,
#   's': 13,
#   's%': 0.1538,
#   'toi': 1276.6666},
#  'Claude Giroux': {'a': 11,
#   'bs': 9,
#   'g': 9,
#   'gp': 17,
#   's': 34,
#   's%': 0.2647,
#   'toi': 1188.8235},
#  'Clayton Keller': {'a': 6,
#   'bs': 8,
#   'g': 11,
#   'gp': 19,
#   's': 61,
#   's%': 0.1803,
#   'toi': 1186.7894},
#  'Cody Ceci': {'a': 1,
#   'bs': 43,
#   'g': 2,
#   'gp': 16,
#   's': 29,
#   's%': 0.0689,
#   'toi': 1337.625},
#  'Cody Eakin': {'a': 5,
#   'bs': 10,
#   'g': 2,
#   'gp': 16,
#   's': 23,
#   's%': 0.0869,
#   'toi': 1045.5625},
#  'Cody Franson': {'a': 3,
#   'bs': 7,
#   'g': 0,
#   'gp': 8,
#   's': 16,
#   's%': 0.0,
#   'toi': 1104.75},
#  'Cody McLeod': {'a': 1,
#   'bs': 5,
#   'g': 0,
#   'gp': 13,
#   's': 3,
#   's%': 0.0,
#   'toi': 374.5384},
#  'Colin Miller': {'a': 7,
#   'bs': 8,
#   'g': 2,
#   'gp': 16,
#   's': 27,
#   's%': 0.074,
#   'toi': 1081.3125},
#  'Colin Wilson': {'a': 3,
#   'bs': 2,
#   'g': 0,
#   'gp': 10,
#   's': 11,
#   's%': 0.0,
#   'toi': 786.8},
#  'Colton Parayko': {'a': 4,
#   'bs': 20,
#   'g': 1,
#   'gp': 18,
#   's': 47,
#   's%': 0.0212,
#   'toi': 1266.8888},
#  'Colton Sceviour': {'a': 2,
#   'bs': 9,
#   'g': 3,
#   'gp': 10,
#   's': 17,
#   's%': 0.1764,
#   'toi': 699.7},
#  'Colton Sissons': {'a': 2,
#   'bs': 6,
#   'g': 2,
#   'gp': 15,
#   's': 24,
#   's%': 0.0833,
#   'toi': 1008.8666},
#  'Connor Brickley': {'a': 5,
#   'bs': 10,
#   'g': 2,
#   'gp': 12,
#   's': 14,
#   's%': 0.1428,
#   'toi': 726.25},
#  'Connor Brown': {'a': 4,
#   'bs': 11,
#   'g': 7,
#   'gp': 19,
#   's': 19,
#   's%': 0.3684,
#   'toi': 925.0526},
#  'Connor Carrick': {'a': 2,
#   'bs': 12,
#   'g': 1,
#   'gp': 12,
#   's': 13,
#   's%': 0.0769,
#   'toi': 800.0},
#  'Connor McDavid': {'a': 12,
#   'bs': 10,
#   'g': 7,
#   'gp': 17,
#   's': 54,
#   's%': 0.1296,
#   'toi': 1358.2352},
#  'Connor Murphy': {'a': 0,
#   'bs': 13,
#   'g': 1,
#   'gp': 15,
#   's': 15,
#   's%': 0.0666,
#   'toi': 861.6666},
#  'Conor Sheary': {'a': 2,
#   'bs': 6,
#   'g': 6,
#   'gp': 19,
#   's': 40,
#   's%': 0.15,
#   'toi': 848.7894},
#  'Corey Perry': {'a': 7,
#   'bs': 10,
#   'g': 3,
#   'gp': 17,
#   's': 34,
#   's%': 0.0882,
#   'toi': 1089.3529},
#  'Craig Smith': {'a': 2,
#   'bs': 5,
#   'g': 5,
#   'gp': 16,
#   's': 34,
#   's%': 0.147,
#   'toi': 878.375},
#  'Curtis Lazar': {'a': 1,
#   'bs': 4,
#   'g': 0,
#   'gp': 12,
#   's': 11,
#   's%': 0.0,
#   'toi': 634.5},
#  'Dakota Mermis': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 6,
#   's': 6,
#   's%': 0.0,
#   'toi': 603.5},
#  'Dale Weise': {'a': 1,
#   'bs': 2,
#   'g': 2,
#   'gp': 14,
#   's': 14,
#   's%': 0.1428,
#   'toi': 629.9285},
#  'Dalton Prout': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 4,
#   's': 5,
#   's%': 0.0,
#   'toi': 839.25},
#  'Damon Severson': {'a': 4,
#   'bs': 18,
#   'g': 2,
#   'gp': 16,
#   's': 31,
#   's%': 0.0645,
#   'toi': 1188.8125},
#  'Dan Girardi': {'a': 3,
#   'bs': 44,
#   'g': 0,
#   'gp': 18,
#   's': 21,
#   's%': 0.0,
#   'toi': 1008.5},
#  'Dan Hamhuis': {'a': 5,
#   'bs': 20,
#   'g': 1,
#   'gp': 15,
#   's': 9,
#   's%': 0.1111,
#   'toi': 1118.4666},
#  'Daniel Sedin': {'a': 5,
#   'bs': 0,
#   'g': 3,
#   'gp': 17,
#   's': 35,
#   's%': 0.0857,
#   'toi': 847.0588},
#  'Daniel Winnik': {'a': 3,
#   'bs': 18,
#   'g': 2,
#   'gp': 16,
#   's': 16,
#   's%': 0.125,
#   'toi': 859.625},
#  'Danny DeKeyser': {'a': 0,
#   'bs': 10,
#   'g': 0,
#   'gp': 3,
#   's': 0,
#   's%': 0.0,
#   'toi': 1170.0},
#  'Danton Heinen': {'a': 5,
#   'bs': 7,
#   'g': 2,
#   'gp': 12,
#   's': 25,
#   's%': 0.08,
#   'toi': 859.1666},
#  'Darnell Nurse': {'a': 4,
#   'bs': 28,
#   'g': 0,
#   'gp': 17,
#   's': 43,
#   's%': 0.0,
#   'toi': 1235.0588},
#  'Darren Helm': {'a': 4,
#   'bs': 9,
#   'g': 3,
#   'gp': 18,
#   's': 31,
#   's%': 0.0967,
#   'toi': 950.0555},
#  'David Backes': {'a': 1,
#   'bs': 4,
#   'g': 0,
#   'gp': 5,
#   's': 14,
#   's%': 0.0,
#   'toi': 1054.6},
#  'David Booth': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 4,
#   's': 3,
#   's%': 0.0,
#   'toi': 296.0},
#  'David Desharnais': {'a': 6,
#   'bs': 7,
#   'g': 2,
#   'gp': 18,
#   's': 16,
#   's%': 0.125,
#   'toi': 818.1111},
#  'David Krejci': {'a': 5,
#   'bs': 4,
#   'g': 1,
#   'gp': 6,
#   's': 7,
#   's%': 0.1428,
#   'toi': 1035.0},
#  'David Pastrnak': {'a': 7,
#   'bs': 6,
#   'g': 10,
#   'gp': 16,
#   's': 48,
#   's%': 0.2083,
#   'toi': 1150.375},
#  'David Perron': {'a': 9,
#   'bs': 5,
#   'g': 5,
#   'gp': 16,
#   's': 35,
#   's%': 0.1428,
#   'toi': 1085.125},
#  'David Savard': {'a': 4,
#   'bs': 31,
#   'g': 2,
#   'gp': 18,
#   's': 39,
#   's%': 0.0512,
#   'toi': 1181.7777},
#  'Denis Malgin': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 6,
#   's%': 0.0,
#   'toi': 573.2},
#  'Dennis Rasmussen': {'a': 1,
#   'bs': 10,
#   'g': 1,
#   'gp': 15,
#   's': 14,
#   's%': 0.0714,
#   'toi': 568.1333},
#  'Dennis Seidenberg': {'a': 2,
#   'bs': 10,
#   'g': 0,
#   'gp': 7,
#   's': 6,
#   's%': 0.0,
#   'toi': 1123.0},
#  'Derek Dorsett': {'a': 2,
#   'bs': 12,
#   'g': 7,
#   'gp': 17,
#   's': 24,
#   's%': 0.2916,
#   'toi': 922.7647},
#  'Derek Forbort': {'a': 5,
#   'bs': 39,
#   'g': 0,
#   'gp': 17,
#   's': 23,
#   's%': 0.0,
#   'toi': 1301.8235},
#  'Derek Grant': {'a': 6,
#   'bs': 15,
#   'g': 3,
#   'gp': 17,
#   's': 18,
#   's%': 0.1666,
#   'toi': 793.2352},
#  'Derek MacKenzie': {'a': 4,
#   'bs': 14,
#   'g': 0,
#   'gp': 16,
#   's': 22,
#   's%': 0.0,
#   'toi': 715.0625},
#  'Derek Ryan': {'a': 5,
#   'bs': 7,
#   'g': 3,
#   'gp': 16,
#   's': 22,
#   's%': 0.1363,
#   'toi': 980.1875},
#  'Derek Stepan': {'a': 6,
#   'bs': 9,
#   'g': 2,
#   'gp': 19,
#   's': 51,
#   's%': 0.0392,
#   'toi': 1220.3157},
#  'Derick Brassard': {'a': 9,
#   'bs': 6,
#   'g': 6,
#   'gp': 16,
#   's': 44,
#   's%': 0.1363,
#   'toi': 1173.1875},
#  'Derrick Pouliot': {'a': 3,
#   'bs': 11,
#   'g': 0,
#   'gp': 14,
#   's': 21,
#   's%': 0.0,
#   'toi': 1013.4285},
#  'Deryk Engelland': {'a': 7,
#   'bs': 29,
#   'g': 2,
#   'gp': 16,
#   's': 25,
#   's%': 0.08,
#   'toi': 1151.625},
#  'Devante Smith-Pelly': {'a': 4,
#   'bs': 21,
#   'g': 2,
#   'gp': 18,
#   's': 30,
#   's%': 0.0666,
#   'toi': 787.7777},
#  'Devin Shore': {'a': 7,
#   'bs': 15,
#   'g': 0,
#   'gp': 17,
#   's': 29,
#   's%': 0.0,
#   'toi': 1032.0588},
#  'Dion Phaneuf': {'a': 6,
#   'bs': 36,
#   'g': 3,
#   'gp': 16,
#   's': 32,
#   's%': 0.0937,
#   'toi': 1276.125},
#  'Dmitrij Jaskin': {'a': 4,
#   'bs': 7,
#   'g': 1,
#   'gp': 15,
#   's': 22,
#   's%': 0.0454,
#   'toi': 668.6666},
#  'Dmitry Kulikov': {'a': 4,
#   'bs': 18,
#   'g': 1,
#   'gp': 14,
#   's': 4,
#   's%': 0.25,
#   'toi': 975.3571},
#  'Dmitry Orlov': {'a': 2,
#   'bs': 22,
#   'g': 1,
#   'gp': 18,
#   's': 34,
#   's%': 0.0294,
#   'toi': 1401.1111},
#  'Dominic Moore': {'a': 1,
#   'bs': 8,
#   'g': 3,
#   'gp': 12,
#   's': 15,
#   's%': 0.2,
#   'toi': 669.5833},
#  'Dougie Hamilton': {'a': 5,
#   'bs': 15,
#   'g': 2,
#   'gp': 16,
#   's': 52,
#   's%': 0.0384,
#   'toi': 1232.9375},
#  'Drake Caggiula': {'a': 1,
#   'bs': 3,
#   'g': 1,
#   'gp': 9,
#   's': 15,
#   's%': 0.0666,
#   'toi': 866.1111},
#  'Drew Doughty': {'a': 8,
#   'bs': 23,
#   'g': 3,
#   'gp': 17,
#   's': 51,
#   's%': 0.0588,
#   'toi': 1627.5294},
#  'Drew Stafford': {'a': 3,
#   'bs': 5,
#   'g': 5,
#   'gp': 14,
#   's': 30,
#   's%': 0.1666,
#   'toi': 930.6428},
#  'Dryden Hunt': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 720.5},
#  'Duncan Keith': {'a': 8,
#   'bs': 36,
#   'g': 0,
#   'gp': 18,
#   's': 45,
#   's%': 0.0,
#   'toi': 1511.1111},
#  'Dustin Brown': {'a': 9,
#   'bs': 6,
#   'g': 8,
#   'gp': 17,
#   's': 52,
#   's%': 0.1538,
#   'toi': 1214.5294},
#  'Dustin Byfuglien': {'a': 10,
#   'bs': 20,
#   'g': 0,
#   'gp': 14,
#   's': 33,
#   's%': 0.0,
#   'toi': 1450.1428},
#  'Dylan DeMelo': {'a': 1,
#   'bs': 3,
#   'g': 0,
#   'gp': 3,
#   's': 4,
#   's%': 0.0,
#   'toi': 883.3333},
#  'Dylan Larkin': {'a': 13,
#   'bs': 6,
#   'g': 2,
#   'gp': 18,
#   's': 47,
#   's%': 0.0425,
#   'toi': 1151.2777},
#  'Dylan Strome': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 3,
#   's%': 0.0,
#   'toi': 729.0},
#  'Elias Lindholm': {'a': 5,
#   'bs': 13,
#   'g': 3,
#   'gp': 16,
#   's': 33,
#   's%': 0.0909,
#   'toi': 1149.0625},
#  'Eric Fehr': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 4,
#   's': 4,
#   's%': 0.0,
#   'toi': 656.0},
#  'Eric Gryba': {'a': 0,
#   'bs': 13,
#   'g': 0,
#   'gp': 14,
#   's': 15,
#   's%': 0.0,
#   'toi': 918.9285},
#  'Eric Staal': {'a': 7,
#   'bs': 9,
#   'g': 5,
#   'gp': 16,
#   's': 46,
#   's%': 0.1086,
#   'toi': 1113.9375},
#  'Erik Gudbranson': {'a': 0,
#   'bs': 22,
#   'g': 0,
#   'gp': 16,
#   's': 17,
#   's%': 0.0,
#   'toi': 1041.5625},
#  'Erik Haula': {'a': 4,
#   'bs': 1,
#   'g': 5,
#   'gp': 12,
#   's': 29,
#   's%': 0.1724,
#   'toi': 972.75},
#  'Erik Johnson': {'a': 6,
#   'bs': 33,
#   'g': 0,
#   'gp': 16,
#   's': 47,
#   's%': 0.0,
#   'toi': 1598.5625},
#  'Erik Karlsson': {'a': 16,
#   'bs': 13,
#   'g': 1,
#   'gp': 11,
#   's': 28,
#   's%': 0.0357,
#   'toi': 1500.1818},
#  'Esa Lindell': {'a': 3,
#   'bs': 21,
#   'g': 4,
#   'gp': 17,
#   's': 38,
#   's%': 0.1052,
#   'toi': 1287.2941},
#  'Evander Kane': {'a': 8,
#   'bs': 6,
#   'g': 9,
#   'gp': 17,
#   's': 82,
#   's%': 0.1097,
#   'toi': 1188.2352},
#  'Evgeni Malkin': {'a': 13,
#   'bs': 5,
#   'g': 7,
#   'gp': 19,
#   's': 55,
#   's%': 0.1272,
#   'toi': 1090.1578},
#  'Evgenii Dadonov': {'a': 9,
#   'bs': 5,
#   'g': 7,
#   'gp': 16,
#   's': 46,
#   's%': 0.1521,
#   'toi': 1165.625},
#  'Evgeny Kuznetsov': {'a': 16,
#   'bs': 7,
#   'g': 3,
#   'gp': 18,
#   's': 42,
#   's%': 0.0714,
#   'toi': 1167.1666},
#  'Filip Chlapik': {'a': 1,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 409.0},
#  'Filip Chytil': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 0,
#   's%': 0.0,
#   'toi': 379.5},
#  'Filip Forsberg': {'a': 8,
#   'bs': 7,
#   'g': 8,
#   'gp': 16,
#   's': 41,
#   's%': 0.1951,
#   'toi': 1100.25},
#  'Francois Beauchemin': {'a': 2,
#   'bs': 33,
#   'g': 0,
#   'gp': 16,
#   's': 23,
#   's%': 0.0,
#   'toi': 1190.6875},
#  'Frank Corrado': {'a': 0,
#   'bs': 5,
#   'g': 0,
#   'gp': 3,
#   's': 3,
#   's%': 0.0,
#   'toi': 666.3333},
#  'Frank Vatrano': {'a': 0,
#   'bs': 4,
#   'g': 2,
#   'gp': 12,
#   's': 17,
#   's%': 0.1176,
#   'toi': 581.5833},
#  'Frans Nielsen': {'a': 2,
#   'bs': 6,
#   'g': 6,
#   'gp': 18,
#   's': 36,
#   's%': 0.1666,
#   'toi': 931.0555},
#  'Freddie Hamilton': {'a': 1,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 2,
#   's%': 0.0,
#   'toi': 471.0},
#  'Frederick Gaudreau': {'a': 2,
#   'bs': 8,
#   'g': 0,
#   'gp': 10,
#   's': 11,
#   's%': 0.0,
#   'toi': 618.0},
#  'Fredrik Claesson': {'a': 0,
#   'bs': 23,
#   'g': 1,
#   'gp': 16,
#   's': 21,
#   's%': 0.0476,
#   'toi': 1038.8125},
#  'Gabriel Bourque': {'a': 0,
#   'bs': 6,
#   'g': 0,
#   'gp': 6,
#   's': 5,
#   's%': 0.0,
#   'toi': 625.1666},
#  'Gabriel Carlsson': {'a': 1,
#   'bs': 5,
#   'g': 0,
#   'gp': 7,
#   's': 11,
#   's%': 0.0,
#   'toi': 640.8571},
#  'Gabriel Dumont': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 7,
#   's': 11,
#   's%': 0.0,
#   'toi': 621.8571},
#  'Gabriel Landeskog': {'a': 6,
#   'bs': 14,
#   'g': 5,
#   'gp': 16,
#   's': 42,
#   's%': 0.119,
#   'toi': 1207.5625},
#  'Garnet Hathaway': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 661.0},
#  'Gemel Smith': {'a': 2,
#   'bs': 5,
#   'g': 1,
#   'gp': 8,
#   's': 9,
#   's%': 0.1111,
#   'toi': 694.625},
#  'Giovanni Fiore': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 473.0},
#  'Greg McKegg': {'a': 2,
#   'bs': 9,
#   'g': 2,
#   'gp': 19,
#   's': 20,
#   's%': 0.1,
#   'toi': 641.1578},
#  'Greg Pateryn': {'a': 0,
#   'bs': 17,
#   'g': 0,
#   'gp': 8,
#   's': 5,
#   's%': 0.0,
#   'toi': 1102.25},
#  'Gustav Forsling': {'a': 5,
#   'bs': 24,
#   'g': 1,
#   'gp': 15,
#   's': 22,
#   's%': 0.0454,
#   'toi': 1064.3333},
#  'Gustav Nyquist': {'a': 3,
#   'bs': 12,
#   'g': 5,
#   'gp': 18,
#   's': 46,
#   's%': 0.1086,
#   'toi': 1028.3333},
#  'Gustav Olofsson': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 9,
#   's': 3,
#   's%': 0.0,
#   'toi': 585.7777},
#  'Hampus Lindholm': {'a': 2,
#   'bs': 17,
#   'g': 3,
#   'gp': 10,
#   's': 19,
#   's%': 0.1578,
#   'toi': 1425.9},
#  'Haydn Fleury': {'a': 3,
#   'bs': 19,
#   'g': 0,
#   'gp': 16,
#   's': 17,
#   's%': 0.0,
#   'toi': 926.75},
#  'Henrik Sedin': {'a': 4,
#   'bs': 1,
#   'g': 1,
#   'gp': 17,
#   's': 10,
#   's%': 0.1,
#   'toi': 848.7058},
#  'Henrik Zetterberg': {'a': 7,
#   'bs': 12,
#   'g': 4,
#   'gp': 18,
#   's': 48,
#   's%': 0.0833,
#   'toi': 1191.0},
#  'Ian Cole': {'a': 1,
#   'bs': 30,
#   'g': 1,
#   'gp': 16,
#   's': 18,
#   's%': 0.0555,
#   'toi': 1005.3125},
#  'Ian McCoshen': {'a': 0,
#   'bs': 17,
#   'g': 3,
#   'gp': 15,
#   's': 13,
#   's%': 0.2307,
#   'toi': 966.6},
#  'Iiro Pakarinen': {'a': 1,
#   'bs': 7,
#   'g': 0,
#   'gp': 14,
#   's': 13,
#   's%': 0.0,
#   'toi': 616.2857},
#  'Ivan Barbashev': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 6,
#   's': 3,
#   's%': 0.0,
#   'toi': 690.1666},
#  'Ivan Provorov': {'a': 6,
#   'bs': 49,
#   'g': 2,
#   'gp': 17,
#   's': 41,
#   's%': 0.0487,
#   'toi': 1478.1176},
#  'J.T. Brown': {'a': 3,
#   'bs': 7,
#   'g': 1,
#   'gp': 10,
#   's': 11,
#   's%': 0.0909,
#   'toi': 629.7},
#  'J.T. Compher': {'a': 3,
#   'bs': 12,
#   'g': 1,
#   'gp': 10,
#   's': 19,
#   's%': 0.0526,
#   'toi': 890.2},
#  'J.T. Miller': {'a': 12,
#   'bs': 4,
#   'g': 3,
#   'gp': 18,
#   's': 23,
#   's%': 0.1304,
#   'toi': 984.5555},
#  'Jaccob Slavin': {'a': 3,
#   'bs': 37,
#   'g': 2,
#   'gp': 16,
#   's': 34,
#   's%': 0.0588,
#   'toi': 1431.75},
#  'Jack Eichel': {'a': 10,
#   'bs': 8,
#   'g': 4,
#   'gp': 17,
#   's': 52,
#   's%': 0.0769,
#   'toi': 1230.2352},
#  'Jack Johnson': {'a': 3,
#   'bs': 34,
#   'g': 1,
#   'gp': 18,
#   's': 19,
#   's%': 0.0526,
#   'toi': 1107.8888},
#  'Jack Rodewald': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 4,
#   's': 0,
#   's%': 0.0,
#   'toi': 438.0},
#  'Jacob Josefson': {'a': 0,
#   'bs': 7,
#   'g': 0,
#   'gp': 6,
#   's': 3,
#   's%': 0.0,
#   'toi': 661.3333},
#  'Jacob Trouba': {'a': 6,
#   'bs': 36,
#   'g': 0,
#   'gp': 16,
#   's': 38,
#   's%': 0.0,
#   'toi': 1331.875},
#  'Jacob de la Rose': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 9,
#   's': 6,
#   's%': 0.0,
#   'toi': 507.3333},
#  'Jaden Schwartz': {'a': 13,
#   'bs': 9,
#   'g': 9,
#   'gp': 18,
#   's': 43,
#   's%': 0.2093,
#   'toi': 1198.6666},
#  'Jake DeBrusk': {'a': 3,
#   'bs': 10,
#   'g': 3,
#   'gp': 15,
#   's': 31,
#   's%': 0.0967,
#   'toi': 898.3333},
#  'Jake Dotchin': {'a': 2,
#   'bs': 19,
#   'g': 1,
#   'gp': 17,
#   's': 16,
#   's%': 0.0625,
#   'toi': 896.5882},
#  'Jake Gardiner': {'a': 7,
#   'bs': 22,
#   'g': 1,
#   'gp': 19,
#   's': 17,
#   's%': 0.0588,
#   'toi': 1339.1578},
#  'Jake Guentzel': {'a': 5,
#   'bs': 9,
#   'g': 5,
#   'gp': 19,
#   's': 41,
#   's%': 0.1219,
#   'toi': 1015.1578},
#  'Jake McCabe': {'a': 3,
#   'bs': 27,
#   'g': 0,
#   'gp': 17,
#   's': 17,
#   's%': 0.0,
#   'toi': 1148.4705},
#  'Jake Muzzin': {'a': 10,
#   'bs': 39,
#   'g': 2,
#   'gp': 17,
#   's': 43,
#   's%': 0.0465,
#   'toi': 1392.7647},
#  'Jake Virtanen': {'a': 2,
#   'bs': 6,
#   'g': 2,
#   'gp': 15,
#   's': 26,
#   's%': 0.0769,
#   'toi': 583.6666},
#  'Jakob Silfverberg': {'a': 4,
#   'bs': 5,
#   'g': 5,
#   'gp': 17,
#   's': 60,
#   's%': 0.0833,
#   'toi': 1131.647},
#  'Jakub Voracek': {'a': 17,
#   'bs': 7,
#   'g': 4,
#   'gp': 17,
#   's': 55,
#   's%': 0.0727,
#   'toi': 1169.4117},
#  'Jakub Vrana': {'a': 3,
#   'bs': 3,
#   'g': 4,
#   'gp': 18,
#   's': 40,
#   's%': 0.1,
#   'toi': 825.7777},
#  'James Neal': {'a': 4,
#   'bs': 7,
#   'g': 9,
#   'gp': 16,
#   's': 44,
#   's%': 0.2045,
#   'toi': 1047.0625},
#  'James van Riemsdyk': {'a': 6,
#   'bs': 5,
#   'g': 9,
#   'gp': 18,
#   's': 52,
#   's%': 0.173,
#   'toi': 835.0555},
#  'Jamie Benn': {'a': 9,
#   'bs': 9,
#   'g': 8,
#   'gp': 17,
#   's': 55,
#   's%': 0.1454,
#   'toi': 1164.4705},
#  'Jamie McGinn': {'a': 4,
#   'bs': 4,
#   'g': 3,
#   'gp': 16,
#   's': 34,
#   's%': 0.0882,
#   'toi': 858.3125},
#  'Jamie Oleksiak': {'a': 0,
#   'bs': 10,
#   'g': 0,
#   'gp': 11,
#   's': 7,
#   's%': 0.0,
#   'toi': 878.0909},
#  'Jan Rutta': {'a': 6,
#   'bs': 25,
#   'g': 3,
#   'gp': 18,
#   's': 24,
#   's%': 0.125,
#   'toi': 1187.3333},
#  'Janne Kuokkanen': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 4,
#   's': 6,
#   's%': 0.0,
#   'toi': 663.75},
#  'Jannik Hansen': {'a': 1,
#   'bs': 0,
#   'g': 0,
#   'gp': 9,
#   's': 11,
#   's%': 0.0,
#   'toi': 787.2222},
#  'Jared Boll': {'a': 0,
#   'bs': 0,
#   'g': 1,
#   'gp': 8,
#   's': 4,
#   's%': 0.25,
#   'toi': 244.5},
#  'Jared McCann': {'a': 3,
#   'bs': 3,
#   'g': 2,
#   'gp': 8,
#   's': 17,
#   's%': 0.1176,
#   'toi': 713.125},
#  'Jared Spurgeon': {'a': 8,
#   'bs': 34,
#   'g': 2,
#   'gp': 16,
#   's': 33,
#   's%': 0.0606,
#   'toi': 1508.375},
#  'Jaromir Jagr': {'a': 3,
#   'bs': 0,
#   'g': 1,
#   'gp': 7,
#   's': 11,
#   's%': 0.0909,
#   'toi': 718.2857},
#  'Jason Chimera': {'a': 2,
#   'bs': 5,
#   'g': 0,
#   'gp': 17,
#   's': 21,
#   's%': 0.0,
#   'toi': 726.8823},
#  'Jason Demers': {'a': 6,
#   'bs': 25,
#   'g': 2,
#   'gp': 19,
#   's': 35,
#   's%': 0.0571,
#   'toi': 1386.2631},
#  'Jason Dickinson': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 3,
#   's': 2,
#   's%': 0.0,
#   'toi': 672.3333},
#  'Jason Garrison': {'a': 1,
#   'bs': 15,
#   'g': 0,
#   'gp': 4,
#   's': 5,
#   's%': 0.0,
#   'toi': 1133.75},
#  'Jason Pominville': {'a': 7,
#   'bs': 11,
#   'g': 6,
#   'gp': 17,
#   's': 34,
#   's%': 0.1764,
#   'toi': 962.2941},
#  'Jason Spezza': {'a': 5,
#   'bs': 5,
#   'g': 1,
#   'gp': 17,
#   's': 38,
#   's%': 0.0263,
#   'toi': 788.4117},
#  'Jason Zucker': {'a': 5,
#   'bs': 5,
#   'g': 9,
#   'gp': 16,
#   's': 46,
#   's%': 0.1956,
#   'toi': 1092.75},
#  'Jay Beagle': {'a': 3,
#   'bs': 9,
#   'g': 2,
#   'gp': 18,
#   's': 13,
#   's%': 0.1538,
#   'toi': 756.2777},
#  'Jaycob Megna': {'a': 1,
#   'bs': 28,
#   'g': 0,
#   'gp': 10,
#   's': 5,
#   's%': 0.0,
#   'toi': 985.1},
#  'Jayson Megna': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 258.0},
#  'Jean-Gabriel Pageau': {'a': 8,
#   'bs': 16,
#   'g': 1,
#   'gp': 16,
#   's': 26,
#   's%': 0.0384,
#   'toi': 951.8125},
#  'Jeff Carter': {'a': 3,
#   'bs': 2,
#   'g': 0,
#   'gp': 6,
#   's': 13,
#   's%': 0.0,
#   'toi': 998.3333},
#  'Jeff Petry': {'a': 3,
#   'bs': 24,
#   'g': 2,
#   'gp': 18,
#   's': 38,
#   's%': 0.0526,
#   'toi': 1272.6111},
#  'Jeff Skinner': {'a': 2,
#   'bs': 5,
#   'g': 9,
#   'gp': 16,
#   's': 61,
#   's%': 0.1475,
#   'toi': 1043.25},
#  'Jesper Bratt': {'a': 8,
#   'bs': 8,
#   'g': 5,
#   'gp': 17,
#   's': 29,
#   's%': 0.1724,
#   'toi': 957.7058},
#  'Jesper Fast': {'a': 6,
#   'bs': 8,
#   'g': 1,
#   'gp': 13,
#   's': 13,
#   's%': 0.0769,
#   'toi': 863.923},
#  'Jesse Puljujarvi': {'a': 0,
#   'bs': 1,
#   'g': 1,
#   'gp': 2,
#   's': 6,
#   's%': 0.1666,
#   'toi': 939.0},
#  'Jimmy Hayes': {'a': 3,
#   'bs': 2,
#   'g': 3,
#   'gp': 15,
#   's': 21,
#   's%': 0.1428,
#   'toi': 821.4},
#  'Jimmy Vesey': {'a': 1,
#   'bs': 10,
#   'g': 4,
#   'gp': 18,
#   's': 32,
#   's%': 0.125,
#   'toi': 833.3888},
#  'Joakim Nordstrom': {'a': 2,
#   'bs': 10,
#   'g': 1,
#   'gp': 16,
#   's': 27,
#   's%': 0.037,
#   'toi': 654.0625},
#  'Joakim Ryan': {'a': 2,
#   'bs': 27,
#   'g': 0,
#   'gp': 14,
#   's': 20,
#   's%': 0.0,
#   'toi': 1080.0714},
#  'Joe Morrow': {'a': 1,
#   'bs': 4,
#   'g': 1,
#   'gp': 8,
#   's': 12,
#   's%': 0.0833,
#   'toi': 806.625},
#  'Joe Pavelski': {'a': 4,
#   'bs': 16,
#   'g': 4,
#   'gp': 16,
#   's': 45,
#   's%': 0.0888,
#   'toi': 1102.4375},
#  'Joe Thornton': {'a': 8,
#   'bs': 6,
#   'g': 2,
#   'gp': 16,
#   's': 20,
#   's%': 0.1,
#   'toi': 1056.8125},
#  'Joel Armia': {'a': 1,
#   'bs': 10,
#   'g': 2,
#   'gp': 13,
#   's': 15,
#   's%': 0.1333,
#   'toi': 596.5384},
#  'Joel Edmundson': {'a': 1,
#   'bs': 51,
#   'g': 5,
#   'gp': 18,
#   's': 34,
#   's%': 0.147,
#   'toi': 1190.5},
#  'Joel Eriksson Ek': {'a': 2,
#   'bs': 12,
#   'g': 1,
#   'gp': 16,
#   's': 32,
#   's%': 0.0312,
#   'toi': 771.5625},
#  'Joel Ward': {'a': 1,
#   'bs': 6,
#   'g': 3,
#   'gp': 11,
#   's': 8,
#   's%': 0.375,
#   'toi': 719.8181},
#  'Johan Larsson': {'a': 2,
#   'bs': 9,
#   'g': 1,
#   'gp': 17,
#   's': 16,
#   's%': 0.0625,
#   'toi': 832.2352},
#  'John Carlson': {'a': 11,
#   'bs': 24,
#   'g': 2,
#   'gp': 18,
#   's': 58,
#   's%': 0.0344,
#   'toi': 1640.2222},
#  'John Hayden': {'a': 5,
#   'bs': 8,
#   'g': 1,
#   'gp': 17,
#   's': 19,
#   's%': 0.0526,
#   'toi': 686.3529},
#  'John Klingberg': {'a': 14,
#   'bs': 31,
#   'g': 4,
#   'gp': 17,
#   's': 42,
#   's%': 0.0952,
#   'toi': 1427.7647},
#  'John Moore': {'a': 5,
#   'bs': 17,
#   'g': 2,
#   'gp': 17,
#   's': 22,
#   's%': 0.0909,
#   'toi': 1174.0588},
#  'John Tavares': {'a': 6,
#   'bs': 5,
#   'g': 13,
#   'gp': 17,
#   's': 54,
#   's%': 0.2407,
#   'toi': 1206.8235},
#  'Johnny Boychuk': {'a': 4,
#   'bs': 41,
#   'g': 1,
#   'gp': 17,
#   's': 49,
#   's%': 0.0204,
#   'toi': 1275.8235},
#  'Johnny Gaudreau': {'a': 16,
#   'bs': 2,
#   'g': 6,
#   'gp': 16,
#   's': 44,
#   's%': 0.1363,
#   'toi': 1147.625},
#  'Johnny Oduya': {'a': 1,
#   'bs': 24,
#   'g': 2,
#   'gp': 13,
#   's': 14,
#   's%': 0.1428,
#   'toi': 1062.0769},
#  'Jon Merrill': {'a': 0,
#   'bs': 6,
#   'g': 0,
#   'gp': 3,
#   's': 2,
#   's%': 0.0,
#   'toi': 1085.6666},
#  'Jonas Brodin': {'a': 0,
#   'bs': 38,
#   'g': 1,
#   'gp': 16,
#   's': 8,
#   's%': 0.125,
#   'toi': 1244.4375},
#  'Jonathan Drouin': {'a': 9,
#   'bs': 5,
#   'g': 3,
#   'gp': 17,
#   's': 50,
#   's%': 0.06,
#   'toi': 1099.8823},
#  'Jonathan Ericsson': {'a': 3,
#   'bs': 12,
#   'g': 1,
#   'gp': 18,
#   's': 26,
#   's%': 0.0384,
#   'toi': 1187.3333},
#  'Jonathan Huberdeau': {'a': 14,
#   'bs': 5,
#   'g': 5,
#   'gp': 16,
#   's': 46,
#   's%': 0.1086,
#   'toi': 1190.5},
#  'Jonathan Marchessault': {'a': 6,
#   'bs': 3,
#   'g': 4,
#   'gp': 13,
#   's': 43,
#   's%': 0.093,
#   'toi': 1021.8461},
#  'Jonathan Toews': {'a': 7,
#   'bs': 6,
#   'g': 4,
#   'gp': 18,
#   's': 51,
#   's%': 0.0784,
#   'toi': 1200.0},
#  'Jonny Brodzinski': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 3,
#   's': 0,
#   's%': 0.0,
#   'toi': 537.0},
#  'Joonas Donskoi': {'a': 3,
#   'bs': 3,
#   'g': 5,
#   'gp': 16,
#   's': 31,
#   's%': 0.1612,
#   'toi': 750.3125},
#  'Jordan Eberle': {'a': 7,
#   'bs': 7,
#   'g': 6,
#   'gp': 17,
#   's': 42,
#   's%': 0.1428,
#   'toi': 974.9411},
#  'Jordan Martinook': {'a': 2,
#   'bs': 5,
#   'g': 1,
#   'gp': 18,
#   's': 25,
#   's%': 0.04,
#   'toi': 800.2777},
#  'Jordan Nolan': {'a': 1,
#   'bs': 3,
#   'g': 0,
#   'gp': 15,
#   's': 7,
#   's%': 0.0,
#   'toi': 557.1333},
#  'Jordan Oesterle': {'a': 1,
#   'bs': 5,
#   'g': 0,
#   'gp': 4,
#   's': 5,
#   's%': 0.0,
#   'toi': 837.25},
#  'Jordan Staal': {'a': 7,
#   'bs': 5,
#   'g': 6,
#   'gp': 16,
#   's': 41,
#   's%': 0.1463,
#   'toi': 1148.625},
#  'Jordan Szwarz': {'a': 3,
#   'bs': 4,
#   'g': 0,
#   'gp': 6,
#   's': 13,
#   's%': 0.0,
#   'toi': 734.5},
#  'Jordan Weal': {'a': 4,
#   'bs': 4,
#   'g': 2,
#   'gp': 15,
#   's': 24,
#   's%': 0.0833,
#   'toi': 807.2666},
#  'Jordie Benn': {'a': 4,
#   'bs': 31,
#   'g': 1,
#   'gp': 17,
#   's': 27,
#   's%': 0.037,
#   'toi': 1102.1764},
#  'Jori Lehtera': {'a': 1,
#   'bs': 3,
#   'g': 0,
#   'gp': 11,
#   's': 7,
#   's%': 0.0,
#   'toi': 678.5454},
#  'Josh Anderson': {'a': 3,
#   'bs': 3,
#   'g': 6,
#   'gp': 16,
#   's': 43,
#   's%': 0.1395,
#   'toi': 1007.25},
#  'Josh Archibald': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 1,
#   's': 1,
#   's%': 0.0,
#   'toi': 651.0},
#  'Josh Bailey': {'a': 15,
#   'bs': 6,
#   'g': 3,
#   'gp': 17,
#   's': 21,
#   's%': 0.1428,
#   'toi': 1023.3529},
#  'Josh Gorges': {'a': 0,
#   'bs': 10,
#   'g': 0,
#   'gp': 5,
#   's': 1,
#   's%': 0.0,
#   'toi': 873.8},
#  'Josh Jooris': {'a': 2,
#   'bs': 4,
#   'g': 2,
#   'gp': 12,
#   's': 23,
#   's%': 0.0869,
#   'toi': 706.75},
#  'Josh Leivo': {'a': 1,
#   'bs': 3,
#   'g': 0,
#   'gp': 5,
#   's': 7,
#   's%': 0.0,
#   'toi': 712.0},
#  'Josh Manson': {'a': 7,
#   'bs': 19,
#   'g': 0,
#   'gp': 17,
#   's': 32,
#   's%': 0.0,
#   'toi': 1262.2941},
#  'Josh Morrissey': {'a': 2,
#   'bs': 36,
#   'g': 2,
#   'gp': 16,
#   's': 17,
#   's%': 0.1176,
#   'toi': 1131.125},
#  'Joshua Ho-Sang': {'a': 4,
#   'bs': 0,
#   'g': 1,
#   'gp': 7,
#   's': 7,
#   's%': 0.1428,
#   'toi': 806.0},
#  'Jujhar Khaira': {'a': 0,
#   'bs': 2,
#   'g': 1,
#   'gp': 7,
#   's': 7,
#   's%': 0.1428,
#   'toi': 533.5714},
#  'Julius Honka': {'a': 0,
#   'bs': 5,
#   'g': 0,
#   'gp': 6,
#   's': 6,
#   's%': 0.0,
#   'toi': 898.0},
#  'Jussi Jokinen': {'a': 1,
#   'bs': 11,
#   'g': 0,
#   'gp': 14,
#   's': 22,
#   's%': 0.0,
#   'toi': 738.7142},
#  'Justin Abdelkader': {'a': 7,
#   'bs': 11,
#   'g': 2,
#   'gp': 17,
#   's': 32,
#   's%': 0.0625,
#   'toi': 1009.3529},
#  'Justin Auger': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 479.5},
#  'Justin Bailey': {'a': 1,
#   'bs': 5,
#   'g': 2,
#   'gp': 7,
#   's': 10,
#   's%': 0.2,
#   'toi': 712.5714},
#  'Justin Braun': {'a': 5,
#   'bs': 38,
#   'g': 0,
#   'gp': 16,
#   's': 11,
#   's%': 0.0,
#   'toi': 1214.75},
#  'Justin Falk': {'a': 0,
#   'bs': 14,
#   'g': 0,
#   'gp': 5,
#   's': 5,
#   's%': 0.0,
#   'toi': 1091.2},
#  'Justin Faulk': {'a': 2,
#   'bs': 23,
#   'g': 1,
#   'gp': 16,
#   's': 50,
#   's%': 0.02,
#   'toi': 1394.75},
#  'Justin Kloos': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 519.0},
#  'Justin Schultz': {'a': 3,
#   'bs': 21,
#   'g': 2,
#   'gp': 13,
#   's': 24,
#   's%': 0.0833,
#   'toi': 1141.3846},
#  'Justin Williams': {'a': 11,
#   'bs': 9,
#   'g': 2,
#   'gp': 16,
#   's': 35,
#   's%': 0.0571,
#   'toi': 1025.125},
#  'Kailer Yamamoto': {'a': 3,
#   'bs': 3,
#   'g': 0,
#   'gp': 9,
#   's': 23,
#   's%': 0.0,
#   'toi': 909.5555},
#  'Kalle Kossila': {'a': 1,
#   'bs': 2,
#   'g': 1,
#   'gp': 6,
#   's': 5,
#   's%': 0.2,
#   'toi': 592.1666},
#  'Karl Alzner': {'a': 4,
#   'bs': 27,
#   'g': 0,
#   'gp': 18,
#   's': 14,
#   's%': 0.0,
#   'toi': 1237.3888},
#  'Kasperi Kapanen': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 3,
#   's': 7,
#   's%': 0.0,
#   'toi': 655.3333},
#  'Keith Yandle': {'a': 5,
#   'bs': 18,
#   'g': 2,
#   'gp': 16,
#   's': 32,
#   's%': 0.0625,
#   'toi': 1415.5625},
#  'Kenny Agostino': {'a': 1,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 11,
#   's%': 0.0,
#   'toi': 722.6},
#  'Kevan Miller': {'a': 3,
#   'bs': 17,
#   'g': 0,
#   'gp': 15,
#   's': 10,
#   's%': 0.0,
#   'toi': 1063.8},
#  'Kevin Bieksa': {'a': 2,
#   'bs': 14,
#   'g': 0,
#   'gp': 12,
#   's': 11,
#   's%': 0.0,
#   'toi': 1033.5},
#  'Kevin Connauton': {'a': 2,
#   'bs': 11,
#   'g': 1,
#   'gp': 15,
#   's': 19,
#   's%': 0.0526,
#   'toi': 819.9333},
#  'Kevin Fiala': {'a': 7,
#   'bs': 3,
#   'g': 0,
#   'gp': 15,
#   's': 18,
#   's%': 0.0,
#   'toi': 837.7333},
#  'Kevin Hayes': {'a': 4,
#   'bs': 8,
#   'g': 3,
#   'gp': 18,
#   's': 37,
#   's%': 0.081,
#   'toi': 1005.8888},
#  'Kevin Labanc': {'a': 4,
#   'bs': 4,
#   'g': 3,
#   'gp': 14,
#   's': 22,
#   's%': 0.1363,
#   'toi': 896.7142},
#  'Kevin Roy': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 2,
#   's': 1,
#   's%': 0.0,
#   'toi': 488.5},
#  'Kevin Shattenkirk': {'a': 12,
#   'bs': 28,
#   'g': 5,
#   'gp': 18,
#   's': 34,
#   's%': 0.147,
#   'toi': 1271.9444},
#  'Klas Dahlbeck': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 3,
#   's': 4,
#   's%': 0.0,
#   'toi': 734.3333},
#  'Korbinian Holzer': {'a': 0,
#   'bs': 7,
#   'g': 0,
#   'gp': 6,
#   's': 5,
#   's%': 0.0,
#   'toi': 910.6666},
#  'Kris Letang': {'a': 12,
#   'bs': 31,
#   'g': 1,
#   'gp': 19,
#   's': 58,
#   's%': 0.0172,
#   'toi': 1560.1578},
#  'Kris Russell': {'a': 4,
#   'bs': 41,
#   'g': 1,
#   'gp': 17,
#   's': 15,
#   's%': 0.0666,
#   'toi': 1046.9411},
#  'Kris Versteeg': {'a': 3,
#   'bs': 6,
#   'g': 2,
#   'gp': 16,
#   's': 33,
#   's%': 0.0606,
#   'toi': 814.375},
#  'Kurtis MacDermid': {'a': 0,
#   'bs': 11,
#   'g': 1,
#   'gp': 12,
#   's': 7,
#   's%': 0.1428,
#   'toi': 589.75},
#  'Kyle Brodziak': {'a': 4,
#   'bs': 9,
#   'g': 2,
#   'gp': 18,
#   's': 21,
#   's%': 0.0952,
#   'toi': 692.8888},
#  'Kyle Clifford': {'a': 1,
#   'bs': 1,
#   'g': 0,
#   'gp': 3,
#   's': 4,
#   's%': 0.0,
#   'toi': 529.3333},
#  'Kyle Connor': {'a': 4,
#   'bs': 5,
#   'g': 4,
#   'gp': 11,
#   's': 20,
#   's%': 0.2,
#   'toi': 1089.4545},
#  'Kyle Okposo': {'a': 4,
#   'bs': 4,
#   'g': 2,
#   'gp': 15,
#   's': 34,
#   's%': 0.0588,
#   'toi': 1028.8},
#  'Kyle Palmieri': {'a': 5,
#   'bs': 8,
#   'g': 4,
#   'gp': 10,
#   's': 28,
#   's%': 0.1428,
#   'toi': 1024.8},
#  'Kyle Quincey': {'a': 3,
#   'bs': 14,
#   'g': 0,
#   'gp': 12,
#   's': 8,
#   's%': 0.0,
#   'toi': 904.4166},
#  'Kyle Turris': {'a': 7,
#   'bs': 6,
#   'g': 4,
#   'gp': 12,
#   's': 28,
#   's%': 0.1428,
#   'toi': 1191.25},
#  'Lance Bouma': {'a': 4,
#   'bs': 10,
#   'g': 1,
#   'gp': 18,
#   's': 20,
#   's%': 0.05,
#   'toi': 580.2222},
#  'Landon Ferraro': {'a': 0,
#   'bs': 0,
#   'g': 1,
#   'gp': 2,
#   's': 3,
#   's%': 0.3333,
#   'toi': 265.0},
#  'Lars Eller': {'a': 8,
#   'bs': 11,
#   'g': 3,
#   'gp': 17,
#   's': 31,
#   's%': 0.0967,
#   'toi': 883.8235},
#  'Lawson Crouse': {'a': 0,
#   'bs': 6,
#   'g': 0,
#   'gp': 7,
#   's': 11,
#   's%': 0.0,
#   'toi': 618.8571},
#  'Leo Komarov': {'a': 4,
#   'bs': 11,
#   'g': 2,
#   'gp': 19,
#   's': 29,
#   's%': 0.0689,
#   'toi': 942.1052},
#  'Leon Draisaitl': {'a': 7,
#   'bs': 3,
#   'g': 5,
#   'gp': 13,
#   's': 37,
#   's%': 0.1351,
#   'toi': 1220.4615},
#  "Liam O'Brien": {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 3,
#   's': 1,
#   's%': 0.0,
#   'toi': 415.0},
#  'Logan Brown': {'a': 1,
#   'bs': 1,
#   'g': 0,
#   'gp': 4,
#   's': 4,
#   's%': 0.0,
#   'toi': 487.75},
#  'Logan Couture': {'a': 5,
#   'bs': 16,
#   'g': 10,
#   'gp': 16,
#   's': 44,
#   's%': 0.2272,
#   'toi': 1093.125},
#  'Logan Shaw': {'a': 3,
#   'bs': 8,
#   'g': 1,
#   'gp': 17,
#   's': 30,
#   's%': 0.0333,
#   'toi': 722.0},
#  'Loui Eriksson': {'a': 1,
#   'bs': 2,
#   'g': 0,
#   'gp': 5,
#   's': 7,
#   's%': 0.0,
#   'toi': 793.8},
#  'Luca Sbisa': {'a': 7,
#   'bs': 30,
#   'g': 1,
#   'gp': 16,
#   's': 14,
#   's%': 0.0714,
#   'toi': 1223.5},
#  'Lukas Sedlak': {'a': 0,
#   'bs': 3,
#   'g': 2,
#   'gp': 8,
#   's': 13,
#   's%': 0.1538,
#   'toi': 598.125},
#  'Luke Glendening': {'a': 0,
#   'bs': 16,
#   'g': 3,
#   'gp': 18,
#   's': 26,
#   's%': 0.1153,
#   'toi': 740.5555},
#  'Luke Kunin': {'a': 2,
#   'bs': 6,
#   'g': 2,
#   'gp': 13,
#   's': 22,
#   's%': 0.0909,
#   'toi': 806.8461},
#  'Luke Schenn': {'a': 2,
#   'bs': 29,
#   'g': 0,
#   'gp': 19,
#   's': 17,
#   's%': 0.0,
#   'toi': 944.2105},
#  'Luke Witkowski': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 7,
#   's': 3,
#   's%': 0.0,
#   'toi': 342.1428},
#  'MacKenzie Weegar': {'a': 0,
#   'bs': 14,
#   'g': 1,
#   'gp': 7,
#   's': 6,
#   's%': 0.1666,
#   'toi': 816.2857},
#  'Madison Bowey': {'a': 5,
#   'bs': 11,
#   'g': 0,
#   'gp': 12,
#   's': 11,
#   's%': 0.0,
#   'toi': 891.6666},
#  'Magnus Paajarvi': {'a': 1,
#   'bs': 5,
#   'g': 2,
#   'gp': 18,
#   's': 24,
#   's%': 0.0833,
#   'toi': 679.6111},
#  'Marc Methot': {'a': 0,
#   'bs': 22,
#   'g': 0,
#   'gp': 15,
#   's': 13,
#   's%': 0.0,
#   'toi': 1162.7333},
#  'Marc Staal': {'a': 2,
#   'bs': 25,
#   'g': 1,
#   'gp': 18,
#   's': 13,
#   's%': 0.0769,
#   'toi': 1070.7222},
#  'Marc-Edouard Vlasic': {'a': 3,
#   'bs': 26,
#   'g': 1,
#   'gp': 15,
#   's': 26,
#   's%': 0.0384,
#   'toi': 1306.4666},
#  'Marco Scandella': {'a': 3,
#   'bs': 28,
#   'g': 0,
#   'gp': 17,
#   's': 38,
#   's%': 0.0,
#   'toi': 1418.9411},
#  'Marcus Foligno': {'a': 3,
#   'bs': 8,
#   'g': 3,
#   'gp': 15,
#   's': 13,
#   's%': 0.2307,
#   'toi': 752.8},
#  'Marcus Johansson': {'a': 2,
#   'bs': 2,
#   'g': 3,
#   'gp': 10,
#   's': 11,
#   's%': 0.2727,
#   'toi': 855.5},
#  'Marcus Kruger': {'a': 1,
#   'bs': 4,
#   'g': 0,
#   'gp': 16,
#   's': 13,
#   's%': 0.0,
#   'toi': 662.8125},
#  'Mario Kempe': {'a': 2,
#   'bs': 10,
#   'g': 2,
#   'gp': 16,
#   's': 19,
#   's%': 0.1052,
#   'toi': 693.6875},
#  'Mark Alt': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 4,
#   's': 4,
#   's%': 0.0,
#   'toi': 795.0},
#  'Mark Barberio': {'a': 2,
#   'bs': 19,
#   'g': 1,
#   'gp': 14,
#   's': 12,
#   's%': 0.0833,
#   'toi': 1037.7857},
#  'Mark Borowiecki': {'a': 1,
#   'bs': 11,
#   'g': 1,
#   'gp': 9,
#   's': 14,
#   's%': 0.0714,
#   'toi': 793.6666},
#  'Mark Giordano': {'a': 3,
#   'bs': 44,
#   'g': 2,
#   'gp': 16,
#   's': 37,
#   's%': 0.054,
#   'toi': 1438.9375},
#  'Mark Jankowski': {'a': 0,
#   'bs': 6,
#   'g': 1,
#   'gp': 8,
#   's': 8,
#   's%': 0.125,
#   'toi': 669.5},
#  'Mark Letestu': {'a': 1,
#   'bs': 6,
#   'g': 2,
#   'gp': 17,
#   's': 29,
#   's%': 0.0689,
#   'toi': 793.4705},
#  'Mark Pysyk': {'a': 1,
#   'bs': 24,
#   'g': 2,
#   'gp': 16,
#   's': 18,
#   's%': 0.1111,
#   'toi': 1117.3125},
#  'Mark Scheifele': {'a': 11,
#   'bs': 9,
#   'g': 10,
#   'gp': 16,
#   's': 32,
#   's%': 0.3125,
#   'toi': 1290.1875},
#  'Mark Stone': {'a': 7,
#   'bs': 11,
#   'g': 12,
#   'gp': 16,
#   's': 47,
#   's%': 0.2553,
#   'toi': 1240.8125},
#  'Mark Streit': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 3,
#   's%': 0.0,
#   'toi': 853.0},
#  'Marko Dano': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 6,
#   's': 1,
#   's%': 0.0,
#   'toi': 434.8333},
#  'Markus Granlund': {'a': 1,
#   'bs': 5,
#   'g': 2,
#   'gp': 16,
#   's': 24,
#   's%': 0.0833,
#   'toi': 1026.625},
#  'Markus Hannikainen': {'a': 2,
#   'bs': 4,
#   'g': 2,
#   'gp': 9,
#   's': 10,
#   's%': 0.2,
#   'toi': 521.8888},
#  'Markus Nutivaara': {'a': 5,
#   'bs': 12,
#   'g': 0,
#   'gp': 13,
#   's': 20,
#   's%': 0.0,
#   'toi': 868.0},
#  'Martin Frk': {'a': 3,
#   'bs': 3,
#   'g': 6,
#   'gp': 18,
#   's': 29,
#   's%': 0.2068,
#   'toi': 680.7222},
#  'Martin Hanzal': {'a': 1,
#   'bs': 12,
#   'g': 1,
#   'gp': 14,
#   's': 28,
#   's%': 0.0357,
#   'toi': 866.5},
#  'Martin Necas': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 414.0},
#  'Mathew Barzal': {'a': 11,
#   'bs': 6,
#   'g': 3,
#   'gp': 17,
#   's': 34,
#   's%': 0.0882,
#   'toi': 949.7058},
#  'Mathieu Perreault': {'a': 2,
#   'bs': 3,
#   'g': 1,
#   'gp': 5,
#   's': 9,
#   's%': 0.1111,
#   'toi': 925.0},
#  'Mats Zuccarello': {'a': 10,
#   'bs': 12,
#   'g': 3,
#   'gp': 18,
#   's': 34,
#   's%': 0.0882,
#   'toi': 1152.5555},
#  'Matt Bartkowski': {'a': 0,
#   'bs': 7,
#   'g': 0,
#   'gp': 10,
#   's': 8,
#   's%': 0.0,
#   'toi': 712.7},
#  'Matt Beleskey': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 12,
#   's': 17,
#   's%': 0.0,
#   'toi': 664.4166},
#  'Matt Benning': {'a': 1,
#   'bs': 14,
#   'g': 1,
#   'gp': 14,
#   's': 30,
# ...
#   's': 8,
#   's%': 0.0,
#   'toi': 679.0},
#  'Radek Faksa': {'a': 4,
#   'bs': 9,
#   'g': 3,
#   'gp': 16,
#   's': 24,
#   's%': 0.125,
#   'toi': 727.75},
#  'Radim Vrbata': {'a': 7,
#   'bs': 6,
#   'g': 3,
#   'gp': 16,
#   's': 40,
#   's%': 0.075,
#   'toi': 889.25},
#  'Radko Gudas': {'a': 2,
#   'bs': 20,
#   'g': 0,
#   'gp': 15,
#   's': 32,
#   's%': 0.0,
#   'toi': 980.8},
#  'Rasmus Andersson': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 1,
#   's': 0,
#   's%': 0.0,
#   'toi': 836.0},
#  'Rasmus Ristolainen': {'a': 5,
#   'bs': 15,
#   'g': 0,
#   'gp': 13,
#   's': 32,
#   's%': 0.0,
#   'toi': 1629.5384},
#  'Reilly Smith': {'a': 8,
#   'bs': 5,
#   'g': 5,
#   'gp': 16,
#   's': 27,
#   's%': 0.1851,
#   'toi': 1114.1875},
#  'Remi Elie': {'a': 0,
#   'bs': 4,
#   'g': 1,
#   'gp': 13,
#   's': 12,
#   's%': 0.0833,
#   'toi': 599.7692},
#  'Richard Panik': {'a': 5,
#   'bs': 12,
#   'g': 5,
#   'gp': 18,
#   's': 42,
#   's%': 0.119,
#   'toi': 925.5},
#  'Rick Nash': {'a': 3,
#   'bs': 10,
#   'g': 6,
#   'gp': 18,
#   's': 65,
#   's%': 0.0923,
#   'toi': 1016.0555},
#  'Rickard Rakell': {'a': 8,
#   'bs': 6,
#   'g': 6,
#   'gp': 17,
#   's': 47,
#   's%': 0.1276,
#   'toi': 1224.5294},
#  'Riley Nash': {'a': 2,
#   'bs': 16,
#   'g': 1,
#   'gp': 16,
#   's': 23,
#   's%': 0.0434,
#   'toi': 937.375},
#  'Riley Sheahan': {'a': 1,
#   'bs': 14,
#   'g': 0,
#   'gp': 18,
#   's': 15,
#   's%': 0.0,
#   'toi': 756.7777},
#  "Rob O'Gara": {'a': 0,
#   'bs': 7,
#   'g': 0,
#   'gp': 4,
#   's': 1,
#   's%': 0.0,
#   'toi': 739.75},
#  'Robert Bortuzzo': {'a': 3,
#   'bs': 26,
#   'g': 1,
#   'gp': 18,
#   's': 21,
#   's%': 0.0476,
#   'toi': 940.2777},
#  'Robert Hagg': {'a': 2,
#   'bs': 26,
#   'g': 0,
#   'gp': 17,
#   's': 21,
#   's%': 0.0,
#   'toi': 1155.4117},
#  'Rocco Grimaldi': {'a': 2,
#   'bs': 5,
#   'g': 1,
#   'gp': 5,
#   's': 6,
#   's%': 0.1666,
#   'toi': 586.4},
#  'Roland McKeown': {'a': 2,
#   'bs': 3,
#   'g': 0,
#   'gp': 2,
#   's': 3,
#   's%': 0.0,
#   'toi': 556.5},
#  'Roman Josi': {'a': 4,
#   'bs': 17,
#   'g': 4,
#   'gp': 13,
#   's': 54,
#   's%': 0.074,
#   'toi': 1556.0769},
#  'Roman Polak': {'a': 1,
#   'bs': 6,
#   'g': 0,
#   'gp': 5,
#   's': 4,
#   's%': 0.0,
#   'toi': 892.6},
#  'Ron Hainsey': {'a': 9,
#   'bs': 37,
#   'g': 0,
#   'gp': 19,
#   's': 16,
#   's%': 0.0,
#   'toi': 1304.7894},
#  'Ryan Callahan': {'a': 2,
#   'bs': 10,
#   'g': 1,
#   'gp': 17,
#   's': 27,
#   's%': 0.037,
#   'toi': 776.4705},
#  'Ryan Carpenter': {'a': 0,
#   'bs': 5,
#   'g': 0,
#   'gp': 10,
#   's': 13,
#   's%': 0.0,
#   'toi': 716.9},
#  'Ryan Dzingel': {'a': 1,
#   'bs': 4,
#   'g': 5,
#   'gp': 16,
#   's': 28,
#   's%': 0.1785,
#   'toi': 1003.75},
#  'Ryan Getzlaf': {'a': 6,
#   'bs': 7,
#   'g': 1,
#   'gp': 6,
#   's': 10,
#   's%': 0.1,
#   'toi': 1154.3333},
#  'Ryan Hartman': {'a': 6,
#   'bs': 6,
#   'g': 4,
#   'gp': 17,
#   's': 29,
#   's%': 0.1379,
#   'toi': 802.3529},
#  'Ryan Johansen': {'a': 8,
#   'bs': 3,
#   'g': 0,
#   'gp': 16,
#   's': 21,
#   's%': 0.0,
#   'toi': 1124.6875},
#  'Ryan McDonagh': {'a': 12,
#   'bs': 37,
#   'g': 0,
#   'gp': 18,
#   's': 30,
#   's%': 0.0,
#   'toi': 1387.2222},
#  'Ryan Murray': {'a': 3,
#   'bs': 32,
#   'g': 1,
#   'gp': 18,
#   's': 18,
#   's%': 0.0555,
#   'toi': 1028.2777},
#  'Ryan Nugent-Hopkins': {'a': 6,
#   'bs': 9,
#   'g': 6,
#   'gp': 17,
#   's': 41,
#   's%': 0.1463,
#   'toi': 1094.5294},
#  "Ryan O'Reilly": {'a': 7,
#   'bs': 12,
#   'g': 6,
#   'gp': 17,
#   's': 43,
#   's%': 0.1395,
#   'toi': 1225.8823},
#  'Ryan Pulock': {'a': 2,
#   'bs': 7,
#   'g': 1,
#   'gp': 8,
#   's': 14,
#   's%': 0.0714,
#   'toi': 897.0},
#  'Ryan Reaves': {'a': 2,
#   'bs': 10,
#   'g': 1,
#   'gp': 19,
#   's': 14,
#   's%': 0.0714,
#   'toi': 438.421},
#  'Ryan Spooner': {'a': 1,
#   'bs': 1,
#   'g': 0,
#   'gp': 5,
#   's': 4,
#   's%': 0.0,
#   'toi': 796.6},
#  'Ryan Strome': {'a': 4,
#   'bs': 2,
#   'g': 2,
#   'gp': 17,
#   's': 34,
#   's%': 0.0588,
#   'toi': 883.5294},
#  'Ryan Suter': {'a': 8,
#   'bs': 34,
#   'g': 2,
#   'gp': 16,
#   's': 35,
#   's%': 0.0571,
#   'toi': 1608.4375},
#  'Sam Bennett': {'a': 1,
#   'bs': 8,
#   'g': 0,
#   'gp': 16,
#   's': 18,
#   's%': 0.0,
#   'toi': 802.9375},
#  'Sam Gagner': {'a': 3,
#   'bs': 8,
#   'g': 2,
#   'gp': 17,
#   's': 42,
#   's%': 0.0476,
#   'toi': 863.8235},
#  'Sam Reinhart': {'a': 3,
#   'bs': 7,
#   'g': 2,
#   'gp': 17,
#   's': 28,
#   's%': 0.0714,
#   'toi': 936.9411},
#  'Sami Vatanen': {'a': 1,
#   'bs': 15,
#   'g': 1,
#   'gp': 7,
#   's': 6,
#   's%': 0.1666,
#   'toi': 1256.1428},
#  'Sammy Blais': {'a': 1,
#   'bs': 2,
#   'g': 0,
#   'gp': 4,
#   's': 3,
#   's%': 0.0,
#   'toi': 835.5},
#  'Samuel Girard': {'a': 3,
#   'bs': 7,
#   'g': 1,
#   'gp': 7,
#   's': 10,
#   's%': 0.1,
#   'toi': 1106.7142},
#  'Scott Harrington': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 2,
#   's': 0,
#   's%': 0.0,
#   'toi': 470.5},
#  'Scott Hartnell': {'a': 3,
#   'bs': 6,
#   'g': 4,
#   'gp': 16,
#   's': 25,
#   's%': 0.16,
#   'toi': 879.3125},
#  'Scott Laughton': {'a': 2,
#   'bs': 7,
#   'g': 2,
#   'gp': 17,
#   's': 25,
#   's%': 0.08,
#   'toi': 788.1764},
#  'Scott Mayfield': {'a': 2,
#   'bs': 16,
#   'g': 2,
#   'gp': 12,
#   's': 16,
#   's%': 0.125,
#   'toi': 1019.75},
#  'Scott Wilson': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 13,
#   's': 12,
#   's%': 0.0,
#   'toi': 495.1538},
#  'Scottie Upshall': {'a': 5,
#   'bs': 8,
#   'g': 2,
#   'gp': 18,
#   's': 15,
#   's%': 0.1333,
#   'toi': 680.5555},
#  'Sean Couturier': {'a': 9,
#   'bs': 10,
#   'g': 10,
#   'gp': 17,
#   's': 55,
#   's%': 0.1818,
#   'toi': 1245.1176},
#  'Sean Kuraly': {'a': 2,
#   'bs': 3,
#   'g': 2,
#   'gp': 16,
#   's': 33,
#   's%': 0.0606,
#   'toi': 699.125},
#  'Sean Monahan': {'a': 8,
#   'bs': 4,
#   'g': 8,
#   'gp': 16,
#   's': 46,
#   's%': 0.1739,
#   'toi': 1080.75},
#  'Sebastian Aho': {'a': 10,
#   'bs': 3,
#   'g': 1,
#   'gp': 16,
#   's': 46,
#   's%': 0.0217,
#   'toi': 1092.625},
#  'Seth Griffith': {'a': 1,
#   'bs': 2,
#   'g': 2,
#   'gp': 14,
#   's': 10,
#   's%': 0.2,
#   'toi': 650.7857},
#  'Seth Jones': {'a': 9,
#   'bs': 26,
#   'g': 3,
#   'gp': 18,
#   's': 47,
#   's%': 0.0638,
#   'toi': 1434.1666},
#  'Shawn Matthias': {'a': 2,
#   'bs': 8,
#   'g': 0,
#   'gp': 16,
#   's': 14,
#   's%': 0.0,
#   'toi': 727.8125},
#  'Shayne Gostisbehere': {'a': 14,
#   'bs': 13,
#   'g': 1,
#   'gp': 14,
#   's': 36,
#   's%': 0.0277,
#   'toi': 1299.5714},
#  'Shea Theodore': {'a': 1,
#   'bs': 4,
#   'g': 0,
#   'gp': 3,
#   's': 3,
#   's%': 0.0,
#   'toi': 909.6666},
#  'Shea Weber': {'a': 8,
#   'bs': 41,
#   'g': 3,
#   'gp': 17,
#   's': 50,
#   's%': 0.06,
#   'toi': 1586.1176},
#  'Sidney Crosby': {'a': 8,
#   'bs': 8,
#   'g': 5,
#   'gp': 19,
#   's': 60,
#   's%': 0.0833,
#   'toi': 1229.5263},
#  'Slater Koekkoek': {'a': 1,
#   'bs': 5,
#   'g': 3,
#   'gp': 8,
#   's': 8,
#   's%': 0.375,
#   'toi': 465.375},
#  'Sonny Milano': {'a': 3,
#   'bs': 3,
#   'g': 5,
#   'gp': 15,
#   's': 20,
#   's%': 0.25,
#   'toi': 619.2},
#  'Stefan Noesen': {'a': 1,
#   'bs': 7,
#   'g': 1,
#   'gp': 12,
#   's': 13,
#   's%': 0.0769,
#   'toi': 694.5833},
#  'Stephen Johns': {'a': 3,
#   'bs': 24,
#   'g': 2,
#   'gp': 14,
#   's': 26,
#   's%': 0.0769,
#   'toi': 1085.6428},
#  'Steven Kampfer': {'a': 0,
#   'bs': 16,
#   'g': 0,
#   'gp': 8,
#   's': 12,
#   's%': 0.0,
#   'toi': 939.75},
#  'Steven Santini': {'a': 4,
#   'bs': 28,
#   'g': 0,
#   'gp': 15,
#   's': 29,
#   's%': 0.0,
#   'toi': 1258.0},
#  'Steven Stamkos': {'a': 23,
#   'bs': 8,
#   'g': 8,
#   'gp': 18,
#   's': 58,
#   's%': 0.1379,
#   'toi': 1157.0},
#  'Sven Andrighetto': {'a': 7,
#   'bs': 5,
#   'g': 5,
#   'gp': 16,
#   's': 32,
#   's%': 0.1562,
#   'toi': 950.8125},
#  'Sven Baertschi': {'a': 7,
#   'bs': 6,
#   'g': 5,
#   'gp': 17,
#   's': 29,
#   's%': 0.1724,
#   'toi': 1012.4117},
#  'T.J. Oshie': {'a': 5,
#   'bs': 13,
#   'g': 7,
#   'gp': 18,
#   's': 35,
#   's%': 0.2,
#   'toi': 1189.8333},
#  'TJ Brodie': {'a': 8,
#   'bs': 27,
#   'g': 2,
#   'gp': 16,
#   's': 25,
#   's%': 0.08,
#   'toi': 1502.4375},
#  'Tage Thompson': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 4,
#   's': 3,
#   's%': 0.0,
#   'toi': 604.5},
#  'Tanner Glass': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 7,
#   's': 5,
#   's%': 0.0,
#   'toi': 577.1428},
#  'Tanner Kero': {'a': 2,
#   'bs': 7,
#   'g': 1,
#   'gp': 8,
#   's': 7,
#   's%': 0.1428,
#   'toi': 686.25},
#  'Tanner Pearson': {'a': 7,
#   'bs': 7,
#   'g': 2,
#   'gp': 17,
#   's': 43,
#   's%': 0.0465,
#   'toi': 965.8823},
#  'Taylor Chorney': {'a': 2,
#   'bs': 16,
#   'g': 1,
#   'gp': 14,
#   's': 8,
#   's%': 0.125,
#   'toi': 791.7142},
#  'Taylor Fedun': {'a': 1,
#   'bs': 7,
#   'g': 0,
#   'gp': 6,
#   's': 8,
#   's%': 0.0,
#   'toi': 924.1666},
#  'Taylor Hall': {'a': 13,
#   'bs': 12,
#   'g': 6,
#   'gp': 17,
#   's': 56,
#   's%': 0.1071,
#   'toi': 1124.0588},
#  'Taylor Leier': {'a': 2,
#   'bs': 7,
#   'g': 0,
#   'gp': 15,
#   's': 23,
#   's%': 0.0,
#   'toi': 690.2666},
#  'Teuvo Teravainen': {'a': 7,
#   'bs': 5,
#   'g': 6,
#   'gp': 16,
#   's': 31,
#   's%': 0.1935,
#   'toi': 953.4375},
#  'Thomas Chabot': {'a': 2,
#   'bs': 3,
#   'g': 0,
#   'gp': 3,
#   's': 4,
#   's%': 0.0,
#   'toi': 820.0},
#  'Thomas Hickey': {'a': 3,
#   'bs': 17,
#   'g': 0,
#   'gp': 13,
#   's': 16,
#   's%': 0.0,
#   'toi': 1055.0},
#  'Thomas Vanek': {'a': 4,
#   'bs': 5,
#   'g': 5,
#   'gp': 17,
#   's': 32,
#   's%': 0.1562,
#   'toi': 801.2352},
#  'Tim Heed': {'a': 5,
#   'bs': 18,
#   'g': 2,
#   'gp': 14,
#   's': 33,
#   's%': 0.0606,
#   'toi': 1054.3571},
#  'Tim Schaller': {'a': 3,
#   'bs': 14,
#   'g': 3,
#   'gp': 16,
#   's': 29,
#   's%': 0.1034,
#   'toi': 870.875},
#  'Timo Meier': {'a': 2,
#   'bs': 8,
#   'g': 1,
#   'gp': 15,
#   's': 33,
#   's%': 0.0303,
#   'toi': 708.0666},
#  'Tobias Rieder': {'a': 2,
#   'bs': 11,
#   'g': 3,
#   'gp': 19,
#   's': 24,
#   's%': 0.125,
#   'toi': 941.6842},
#  'Toby Enstrom': {'a': 2,
#   'bs': 21,
#   'g': 0,
#   'gp': 16,
#   's': 10,
#   's%': 0.0,
#   'toi': 1022.0625},
#  'Tom Kuhnhackl': {'a': 3,
#   'bs': 13,
#   'g': 0,
#   'gp': 19,
#   's': 16,
#   's%': 0.0,
#   'toi': 657.421},
#  'Tom Pyatt': {'a': 6,
#   'bs': 25,
#   'g': 3,
#   'gp': 16,
#   's': 23,
#   's%': 0.1304,
#   'toi': 884.4375},
#  'Tom Wilson': {'a': 3,
#   'bs': 4,
#   'g': 2,
#   'gp': 14,
#   's': 19,
#   's%': 0.1052,
#   'toi': 824.8571},
#  'Tomas Hertl': {'a': 7,
#   'bs': 16,
#   'g': 3,
#   'gp': 16,
#   's': 41,
#   's%': 0.0731,
#   'toi': 1065.625},
#  'Tomas Nosek': {'a': 2,
#   'bs': 6,
#   'g': 2,
#   'gp': 16,
#   's': 17,
#   's%': 0.1176,
#   'toi': 627.625},
#  'Tomas Plekanec': {'a': 3,
#   'bs': 9,
#   'g': 3,
#   'gp': 18,
#   's': 42,
#   's%': 0.0714,
#   'toi': 958.2222},
#  'Tomas Tatar': {'a': 3,
#   'bs': 8,
#   'g': 4,
#   'gp': 18,
#   's': 44,
#   's%': 0.0909,
#   'toi': 1042.5},
#  'Tommy Wingels': {'a': 3,
#   'bs': 10,
#   'g': 1,
#   'gp': 15,
#   's': 20,
#   's%': 0.05,
#   'toi': 635.8},
#  'Tony DeAngelo': {'a': 1,
#   'bs': 2,
#   'g': 0,
#   'gp': 8,
#   's': 14,
#   's%': 0.0,
#   'toi': 758.375},
#  'Torey Krug': {'a': 8,
#   'bs': 13,
#   'g': 3,
#   'gp': 15,
#   's': 29,
#   's%': 0.1034,
#   'toi': 1282.0666},
#  'Torrey Mitchell': {'a': 0,
#   'bs': 6,
#   'g': 0,
#   'gp': 10,
#   's': 8,
#   's%': 0.0,
#   'toi': 561.0},
#  'Travis Hamonic': {'a': 1,
#   'bs': 22,
#   'g': 1,
#   'gp': 13,
#   's': 14,
#   's%': 0.0714,
#   'toi': 1237.1538},
#  'Travis Konecny': {'a': 5,
#   'bs': 8,
#   'g': 2,
#   'gp': 17,
#   's': 30,
#   's%': 0.0666,
#   'toi': 854.1764},
#  'Travis Sanheim': {'a': 2,
#   'bs': 13,
#   'g': 0,
#   'gp': 14,
#   's': 26,
#   's%': 0.0,
#   'toi': 952.0},
#  'Trevor Carrick': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 1,
#   's%': 0.0,
#   'toi': 452.0},
#  'Trevor Daley': {'a': 1,
#   'bs': 22,
#   'g': 0,
#   'gp': 18,
#   's': 26,
#   's%': 0.0,
#   'toi': 1325.2222},
#  'Trevor Lewis': {'a': 3,
#   'bs': 7,
#   'g': 4,
#   'gp': 17,
#   's': 35,
#   's%': 0.1142,
#   'toi': 930.1764},
#  'Trevor van Riemsdyk': {'a': 2,
#   'bs': 19,
#   'g': 0,
#   'gp': 13,
#   's': 25,
#   's%': 0.0,
#   'toi': 948.6923},
#  'Troy Brouwer': {'a': 2,
#   'bs': 6,
#   'g': 0,
#   'gp': 16,
#   's': 14,
#   's%': 0.0,
#   'toi': 802.3125},
#  'Troy Stecher': {'a': 1,
#   'bs': 4,
#   'g': 0,
#   'gp': 8,
#   's': 7,
#   's%': 0.0,
#   'toi': 950.0},
#  'Tucker Poolman': {'a': 0,
#   'bs': 3,
#   'g': 0,
#   'gp': 3,
#   's': 4,
#   's%': 0.0,
#   'toi': 940.6666},
#  'Tyler Bozak': {'a': 4,
#   'bs': 6,
#   'g': 4,
#   'gp': 19,
#   's': 29,
#   's%': 0.1379,
#   'toi': 886.8421},
#  'Tyler Ennis': {'a': 2,
#   'bs': 4,
#   'g': 3,
#   'gp': 16,
#   's': 24,
#   's%': 0.125,
#   'toi': 740.5},
#  'Tyler Graovac': {'a': 0,
#   'bs': 1,
#   'g': 0,
#   'gp': 3,
#   's': 0,
#   's%': 0.0,
#   'toi': 313.0},
#  'Tyler Johnson': {'a': 4,
#   'bs': 9,
#   'g': 4,
#   'gp': 18,
#   's': 32,
#   's%': 0.125,
#   'toi': 962.5},
#  'Tyler Motte': {'a': 1,
#   'bs': 3,
#   'g': 2,
#   'gp': 7,
#   's': 10,
#   's%': 0.2,
#   'toi': 721.4285},
#  'Tyler Myers': {'a': 3,
#   'bs': 18,
#   'g': 2,
#   'gp': 16,
#   's': 20,
#   's%': 0.1,
#   'toi': 1207.25},
#  'Tyler Pitlick': {'a': 2,
#   'bs': 8,
#   'g': 2,
#   'gp': 15,
#   's': 18,
#   's%': 0.1111,
#   'toi': 670.8666},
#  'Tyler Seguin': {'a': 9,
#   'bs': 5,
#   'g': 8,
#   'gp': 17,
#   's': 69,
#   's%': 0.1159,
#   'toi': 1220.1176},
#  'Tyler Toffoli': {'a': 5,
#   'bs': 0,
#   'g': 8,
#   'gp': 17,
#   's': 63,
#   's%': 0.1269,
#   'toi': 968.5294},
#  'Tyson Barrie': {'a': 12,
#   'bs': 21,
#   'g': 2,
#   'gp': 16,
#   's': 40,
#   's%': 0.05,
#   'toi': 1343.3125},
#  'Tyson Jost': {'a': 1,
#   'bs': 3,
#   'g': 1,
#   'gp': 6,
#   's': 10,
#   's%': 0.1,
#   'toi': 813.0},
#  'Vadim Shipachyov': {'a': 0,
#   'bs': 0,
#   'g': 1,
#   'gp': 3,
#   's': 3,
#   's%': 0.3333,
#   'toi': 635.3333},
#  'Valtteri Filppula': {'a': 3,
#   'bs': 18,
#   'g': 6,
#   'gp': 17,
#   's': 21,
#   's%': 0.2857,
#   'toi': 1027.647},
#  'Victor Antipin': {'a': 2,
#   'bs': 10,
#   'g': 0,
#   'gp': 12,
#   's': 11,
#   's%': 0.0,
#   'toi': 875.0833},
#  'Victor Hedman': {'a': 11,
#   'bs': 18,
#   'g': 2,
#   'gp': 18,
#   's': 38,
#   's%': 0.0526,
#   'toi': 1523.7222},
#  'Victor Mete': {'a': 3,
#   'bs': 23,
#   'g': 0,
#   'gp': 18,
#   's': 17,
#   's%': 0.0,
#   'toi': 980.4444},
#  'Victor Rask': {'a': 2,
#   'bs': 5,
#   'g': 3,
#   'gp': 16,
#   's': 28,
#   's%': 0.1071,
#   'toi': 950.125},
#  'Viktor Arvidsson': {'a': 4,
#   'bs': 17,
#   'g': 6,
#   'gp': 16,
#   's': 55,
#   's%': 0.109,
#   'toi': 1097.4375},
#  'Vince Dunn': {'a': 1,
#   'bs': 14,
#   'g': 2,
#   'gp': 18,
#   's': 34,
#   's%': 0.0588,
#   'toi': 1004.1666},
#  'Vincent Trocheck': {'a': 9,
#   'bs': 12,
#   'g': 8,
#   'gp': 16,
#   's': 45,
#   's%': 0.1777,
#   'toi': 1277.4375},
#  'Vladimir Sobotka': {'a': 7,
#   'bs': 9,
#   'g': 3,
#   'gp': 18,
#   's': 27,
#   's%': 0.1111,
#   'toi': 1062.3333},
#  'Vladimir Tarasenko': {'a': 12,
#   'bs': 9,
#   'g': 8,
#   'gp': 18,
#   's': 77,
#   's%': 0.1038,
#   'toi': 1184.2222},
#  'Vladislav Namestnikov': {'a': 10,
#   'bs': 19,
#   'g': 9,
#   'gp': 18,
#   's': 48,
#   's%': 0.1875,
#   'toi': 1094.1111},
#  'Wade Megan': {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 1,
#   's%': 0.0,
#   'toi': 501.0},
#  'Wayne Simmonds': {'a': 5,
#   'bs': 19,
#   'g': 6,
#   'gp': 17,
#   's': 36,
#   's%': 0.1666,
#   'toi': 1089.8235},
#  'Will Butcher': {'a': 13,
#   'bs': 14,
#   'g': 0,
#   'gp': 17,
#   's': 15,
#   's%': 0.0,
#   'toi': 941.3529},
#  "Will O'Neill": {'a': 0,
#   'bs': 0,
#   'g': 0,
#   'gp': 1,
#   's': 3,
#   's%': 0.0,
#   'toi': 565.0},
#  'William Carrier': {'a': 1,
#   'bs': 7,
#   'g': 1,
#   'gp': 15,
#   's': 22,
#   's%': 0.0454,
#   'toi': 537.4},
#  'William Karlsson': {'a': 6,
#   'bs': 10,
#   'g': 6,
#   'gp': 16,
#   's': 31,
#   's%': 0.1935,
#   'toi': 1087.3125},
#  'William Nylander': {'a': 10,
#   'bs': 1,
#   'g': 3,
#   'gp': 19,
#   's': 55,
#   's%': 0.0545,
#   'toi': 1039.0526},
#  'Xavier Ouellet': {'a': 0,
#   'bs': 25,
#   'g': 0,
#   'gp': 18,
#   's': 26,
#   's%': 0.0,
#   'toi': 974.6666},
#  'Yanni Gourde': {'a': 8,
#   'bs': 11,
#   'g': 4,
#   'gp': 18,
#   's': 34,
#   's%': 0.1176,
#   'toi': 1033.8888},
#  'Yannick Weber': {'a': 2,
#   'bs': 8,
#   'g': 0,
#   'gp': 12,
#   's': 6,
#   's%': 0.0,
#   'toi': 674.3333},
#  'Yohann Auvitu': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 6,
#   's': 15,
#   's%': 0.0,
#   'toi': 865.8333},
#  'Zac Dalpe': {'a': 0,
#   'bs': 4,
#   'g': 0,
#   'gp': 10,
#   's': 17,
#   's%': 0.0,
#   'toi': 462.0},
#  'Zac Rinaldo': {'a': 0,
#   'bs': 4,
#   'g': 2,
#   'gp': 14,
#   's': 16,
#   's%': 0.125,
#   'toi': 639.6428},
#  'Zach Hyman': {'a': 6,
#   'bs': 11,
#   'g': 4,
#   'gp': 19,
#   's': 37,
#   's%': 0.1081,
#   'toi': 1041.7368},
#  'Zach Redmond': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 3,
#   's': 7,
#   's%': 0.0,
#   'toi': 868.6666},
#  'Zach Trotman': {'a': 0,
#   'bs': 2,
#   'g': 0,
#   'gp': 3,
#   's': 6,
#   's%': 0.0,
#   'toi': 767.0},
#  'Zach Werenski': {'a': 6,
#   'bs': 17,
#   'g': 4,
#   'gp': 18,
#   's': 50,
#   's%': 0.08,
#   'toi': 1358.2777},
#  'Zack Kassian': {'a': 2,
#   'bs': 1,
#   'g': 0,
#   'gp': 17,
#   's': 23,
#   's%': 0.0,
#   'toi': 712.2352},
#  'Zack Mitchell': {'a': 1,
#   'bs': 1,
#   'g': 1,
#   'gp': 5,
#   's': 4,
#   's%': 0.25,
#   'toi': 574.4},
#  'Zack Smith': {'a': 6,
#   'bs': 4,
#   'g': 0,
#   'gp': 12,
#   's': 23,
#   's%': 0.0,
#   'toi': 1018.75},
#  'Zdeno Chara': {'a': 4,
#   'bs': 23,
#   'g': 1,
#   'gp': 16,
#   's': 19,
#   's%': 0.0526,
#   'toi': 1406.8125},
#  'Zemgus Girgensons': {'a': 2,
#   'bs': 7,
#   'g': 1,
#   'gp': 14,
#   's': 19,
#   's%': 0.0526,
#   'toi': 752.9285}}
